# %% [markdown]
# # Contaminate mock with Photometric weight
#
# **author:** Edmond Chaussidon (CEA Saclay)
#
# **mail:** edmond.chaussidon@cea.fr
#
# This notebook explains how to contaminate mocks (and test the efficiency of the method) from photometric weight. The last part needs ``pycorr`` and ``pypower``.
#
# You need an acces to `/global/cfs/cdirs/desi/`.

# %%
import os
import logging
import fitsio

from regressis import PhotoWeight
from regressis.mocks import create_flag_imaging_systematic
from regressis.utils import setup_logging, setup_mplstyle

setup_logging()
setup_mplstyle() # On NERSC, you may need to load tex with `module load texlive/2019`

logger = logging.getLogger("Notebook")

data_dir = '../regressis/tests/test_data'

# %%
# %matplotlib inline

# %%
# I/O functions:
def _desi_mock_filename(tracer='LRG', ph=0):
    """Collect the name of DESI Mocks in NERSC."""
    mock_dir='/global/cfs/cdirs/desi/cosmosim/FirstGenMocks/AbacusSummit/CutSky/'
    z_dic={'LRG':0.8,'ELG':1.1,'QSO':1.4}
    fname=f'{mock_dir}{tracer}/z{z_dic[tracer]:5.3f}/cutsky_{tracer}_z{z_dic[tracer]:5.3f}_AbacusSummit_base_c000_ph{ph:003d}.fits'
    return fname


def _save_flag(flag, colname, savename):
    """Save flag with a specif colname in .fits file called savename"""
    fits = fitsio.FITS(savename, 'rw', clobber=True) #clobber to overwrite file
    if len(flag) == 1:
        to_save = np.array(flag[0], dtype=[(colname[0], 'bool')])
        fits.write(to_save)
    elif len(flag) == 2:
        fits.write(flag, names=colname)
    fits.close()
    logger.info(f'WRITE flag in {savename}')

# %% [markdown]
# -----
#
# ## Load data and apply contamination:
#
# For this example, we will use the SV3 LRG target density (with **only** standard maskbit from the Imaging legacy survey) to estimate the imaging systematic effects. This target selection is known to be contaminated by stars near the galactic plane. Additional masks (around Gaia stars) were developped by Rongpu Zhou to reduce stellar contamination. That is why, the clustering computed at this end does not match the clustering computed in Zhou et al. 2020.

# %%
version = 'MAIN'
tracer = 'ELG'
nside = 512

# Load photometric weight
# wsys = PhotoWeight.load(os.path.join(data_dir, f'{version}_{tracer}_imaging_weight_256.npy'))
wsys = PhotoWeight.load(os.path.join('/global/cfs/cdirs/desi/users/edmondc/sys_weight/photo', f'{version}_{tracer}_imaging_weight_{nside}.npy'))

# Load mock
mock_name = _desi_mock_filename(tracer=tracer, ph=0)
logger.info(f"Read Mock: {mock_name}")
mock = fitsio.FITS(mock_name)[1].read()

# Load high density mock flag
flag_dir = mock_name + '_flags'
logger.info(f"Read Mock flag: {os.path.join(flag_dir, 'pnz.fits')}")
sel_pnz = fitsio.FITS(os.path.join(flag_dir, 'pnz.fits'))[1]['pnz'].read()
# Out:
# [000014.04] 22-07-12 01:21  PhotoWeight          INFO     Load PhotoWeight class from /global/cfs/cdirs/desi/users/edmondc/sys_weight/photo/MAIN_ELG_imaging_weight_512.npy
# [000014.04] 22-07-12 01:21  Notebook             INFO     Read Mock: /global/cfs/cdirs/desi/cosmosim/FirstGenMocks/AbacusSummit/CutSky/ELG/z1.100/cutsky_ELG_z1.100_AbacusSummit_base_c000_ph000.fits
# [000022.20] 22-07-12 01:21  Notebook             INFO     Read Mock flag: /global/cfs/cdirs/desi/cosmosim/FirstGenMocks/AbacusSummit/CutSky/ELG/z1.100/cutsky_ELG_z1.100_AbacusSummit_base_c000_ph000.fits_flags/pnz.fits

# %% [markdown]
# ----
#
# **Implementation:** Starting from a mock with a higher density than the expected density from data, contamination is done removing objects in each pixel. The quantity of objects to remove is defined by $A$ in $N_{mocks} - A = N_{obs}$.
#
# Normalizing A by the density of objects in Mocks we have: $A_{norm} = A / N_{mocks}$ and $A_{norm} = 1 - \dfrac{N_{obs}}{N_{mocks}} = 1 - \dfrac{1}{w_{sys}f}$ where $f$ is the ratio between $N_{mocks}$ and $N_{expected}$. Take care $N_{expected}$ is not the same in each photometric footprint. $N_{expected}$ can be estimated from the data !
#
# -----

# %%
# Warning: use_real_density=True --> does not recover the expected density from Shadab mocks --> OK, it does not have the correct n(z) 
# which are different in the different photometric footprint

# Compute flags to build contaminated mock
# Fix the seed for reproductibility
is_in_wsys_footprint, is_for_wsys_cont, pix_number = create_flag_imaging_systematic(mock, sel_pnz, wsys, use_real_density=True, show=False, savedir=None, seed=123)

if False:
    # Save flags in the flag directory (modify '' by flag_dir in os.path.join()
    save_flag([pix_number, is_in_wsys_footprint, is_for_wsys_cont, wsys(pix_number)], ['HPX', 'IS_IN_WSYS', 'IS_FOR_CONT', 'WSYS'], os.path.join('', 'photo_contamination.fits'))
# Out:
# [000030.73] 22-07-12 01:21  Mocks                INFO     Compute the healpix number at nside=512 for each object in the mock
# [000064.28] 22-07-12 01:22  Mocks                INFO     Use the real density from PhotoWeight class
# [000081.84] 22-07-12 01:22  Mocks                INFO     We remove 76.81% of the objects in the mocks which are in wsys footprint !

# %% [markdown]
# -----
#
# ## Testing the method !

# %%
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp

from regressis import PhotometricDataFrame, Regression, DR9Footprint
from regressis.utils import build_healpix_map
from regressis.plot import plot_moll
from regressis.systematics import plot_systematic_from_map

# %%
# flag for expected n(z) mock
sel_nz = mock['STATUS'] & 2**0 != 0

plt.figure(figsize=(5, 4))
plt.hist(mock['Z'][sel_nz&is_in_wsys_footprint], histtype='step', bins=100, range=(0.0, 2.4), label='expected n(z)')
plt.hist(mock['Z'][sel_pnz&is_in_wsys_footprint], histtype='step', bins=100, range=(0.0, 2.4), label='high density n(z)')
plt.hist(mock['Z'][is_for_wsys_cont], histtype='step', bins=100, range=(0.0, 2.4), label='final n(z)')
plt.legend()
plt.xlabel('z')
plt.tight_layout()
plt.show()

# %%
# Build healpix map:
expected_mock_map = build_healpix_map(nside, mock['RA'], mock['DEC'], precomputed_pix=pix_number, sel=sel_nz, in_deg2=False)
cont_mock_map = build_healpix_map(nside, mock['RA'], mock['DEC'], precomputed_pix=pix_number, sel=is_for_wsys_cont, in_deg2=False)

# %%
plt.hist(expected_mock_map, bins=25, range=(10, 60))
plt.hist(cont_mock_map, bins=25, range=(10, 60))
plt.show()

# %%
wsys.regions
# Out:
# ['North', 'South', 'Des']

# %%
wsys.mean_density_region
# Out:
# {'North': 31.029443719200817,
#  'South': 32.45127245598024,
#  'Des': 30.48623217783907}

# %%
np.mean(cont_mock_map[wsys.mask_region['North']])
# Out:
# 31.326102918680782

# %%
np.mean(wsys.map[wsys.mask_region['South']])
# Out:
# 1.0226555349712596

# %%
plot_moll(wsys.mask_region[wsys.regions[2]])
# Out:
# [083892.82] 22-07-12 00:34  matplotlib.legend    WARNING  No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Compute photometric weight from the contaminated mock (cf photometric_mitigation_* notebook for usefull comments):
wsys_already_computed = False # usefull to avoid to spend time for this computation if already computed

version, suffix_tracer = 'MOCKS', '0'

# Load DR9 footprint:
dr9_footprint = DR9Footprint(256, mask_lmc=False, clear_south=True, mask_around_des=True, cut_desi=False)

# Set parameters for the dataframe:
params = dict()
params['data_dir'] = '../regressis/tests/test_data'
params['output_dir'] = None
params['regions'] = ['North', 'South', 'Des']

# Build PhotometricDataFrame class:
dataframe = PhotometricDataFrame(version, tracer, dr9_footprint, suffix_tracer, **params)

# Load features from params['data_dir']:
logger.info('Features')
dataframe.set_features() 

# Load default fracarea (FRACAREA_12290 from features):
logger.info('Targets')
dataframe.set_targets(targets=cont_mock_map)

# Select which pixels will be kept for the training and compute the normalized density on each selected params['regions']:
logger.info('Build')
dataframe.build(cut_fracarea=True)

if wsys_already_computed:
    # Load computed weight (useful if you don't want to recompute all the time the weight)
    wsys_new = PhotoWeight.load(f'{dataframe.version}_{dataframe.tracer}{dataframe.suffix_tracer}_imaging_weight_256.npy')
else:
    # Run regression and collect computed weight
    regression = Regression(dataframe, regressor='RF', use_kfold=True, n_jobs=62, seed=123)
    wsys_new = regression.get_weight(save=True, savedir='')
# Out:
# [000024.57] 22-07-11 01:16  Footprint            INFO     Load DR9 footprint with mask_lmc=False, clear_south=True, mask_around_des=True and cut_desi=False
# [000024.59] 22-07-11 01:16  DataFrame            INFO     version: MOCKS -- tracer: LRG -- regions: ['North', 'South', 'Des']
# [000024.59] 22-07-11 01:16  Notebook             INFO     Features
# [000024.59] 22-07-11 01:16  DataFrame            INFO     Read ../regressis/tests/test_data/pixweight-dr9-256.fits
# [000025.09] 22-07-11 01:16  DataFrame            INFO     Read ../regressis/tests/test_data/sagittarius_stream_256.npy
# [000025.15] 22-07-11 01:16  DataFrame            INFO     Sanity check: number of NaNs in features: 0
# [000025.15] 22-07-11 01:16  Notebook             INFO     Targets
# [000025.15] 22-07-11 01:16  DataFrame            INFO     Do not find corresponding fracarea map --> use FRACAREA_12290 as default fracarea
# [000025.15] 22-07-11 01:16  DataFrame            INFO     Read ../regressis/tests/test_data/pixweight-dr9-256.fits
# [000025.22] 22-07-11 01:16  Notebook             INFO     Build
# [000025.71] 22-07-11 01:16  DataFrame            INFO     The considered footprint represents 100.00% of the DR9 footprint
# [000025.72] 22-07-11 01:16  DataFrame            INFO     They are 9195 pixels which will be not used for the training i.e. 2.46% of the considered footprint
# [000026.45] 22-07-11 01:16  DataFrame            INFO       ** North: 619.93 -- 1.0000 -- 1.0000
# [000027.17] 22-07-11 01:16  DataFrame            INFO       ** South: 624.39 -- 1.0000 -- 1.0000
# [000027.90] 22-07-11 01:16  DataFrame            INFO       ** Des: 586.41 -- 1.0000 -- 1.0000
# [000027.91] 22-07-11 01:16  Regression           INFO     We use the set of features: ['STARDENS', 'EBV', 'PSFDEPTH_G', 'PSFDEPTH_R', 'PSFDEPTH_Z', 'PSFDEPTH_W1', 'PSFSIZE_G', 'PSFSIZE_R', 'PSFSIZE_Z']
# [000028.64] 22-07-11 01:16  Regression           INFO       ** North :
# [000028.66] 22-07-11 01:16  Regression           INFO         --> Sample size North: 96329 -- Total sample size: 364772 -- Training fraction: 26.41%
# [000028.66] 22-07-11 01:16  Regression           INFO         --> Use k-fold training ? True
# [000028.66] 22-07-11 01:16  Regression           INFO         --> Engine: RF with params: {'n_estimators': 200, 'min_samples_leaf': 20, 'max_depth': None, 'max_leaf_nodes': None, 'n_jobs': 62, 'random_state': 123}
# [000028.67] 22-07-11 01:16  Regression           INFO         --> We use: GroupKFold(n_splits=6) k-fold with group_size = 1000.0
# [000028.68] 22-07-11 01:16  Regression           INFO         --> Train and eval for the fold:
# [000028.68] 22-07-11 01:16  Regression           INFO             * 0
# [000028.69] 22-07-11 01:16  Regression           INFO               --> There are 79536 pixels to train fold 0 which contains 16793 pixels (kept for the global training)
# [000028.69] 22-07-11 01:16  Regression           INFO               --> Features are not normalized
# [000028.69] 22-07-11 01:16  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000040.55] 22-07-11 01:16  Regression           INFO             * 1
# [000040.56] 22-07-11 01:16  Regression           INFO               --> There are 79493 pixels to train fold 1 which contains 16836 pixels (kept for the global training)
# [000040.56] 22-07-11 01:16  Regression           INFO               --> Features are not normalized
# [000040.56] 22-07-11 01:16  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000052.73] 22-07-11 01:17  Regression           INFO             * 2
# [000052.74] 22-07-11 01:17  Regression           INFO               --> There are 80832 pixels to train fold 2 which contains 15497 pixels (kept for the global training)
# [000052.75] 22-07-11 01:17  Regression           INFO               --> Features are not normalized
# [000052.75] 22-07-11 01:17  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000065.26] 22-07-11 01:17  Regression           INFO             * 3
# [000065.27] 22-07-11 01:17  Regression           INFO               --> There are 80533 pixels to train fold 3 which contains 15796 pixels (kept for the global training)
# [000065.27] 22-07-11 01:17  Regression           INFO               --> Features are not normalized
# [000065.28] 22-07-11 01:17  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000077.67] 22-07-11 01:17  Regression           INFO             * 4
# [000077.68] 22-07-11 01:17  Regression           INFO               --> There are 80571 pixels to train fold 4 which contains 15758 pixels (kept for the global training)
# [000077.68] 22-07-11 01:17  Regression           INFO               --> Features are not normalized
# [000077.68] 22-07-11 01:17  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000089.84] 22-07-11 01:17  Regression           INFO             * 5
# [000089.86] 22-07-11 01:17  Regression           INFO               --> There are 80680 pixels to train fold 5 which contains 15649 pixels (kept for the global training)
# [000089.86] 22-07-11 01:17  Regression           INFO               --> Features are not normalized
# [000089.86] 22-07-11 01:17  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000101.97] 22-07-11 01:18  Regression           INFO         --> Done in: 73.281 s
# [000102.81] 22-07-11 01:18  Regression           INFO       ** South :
# [000102.85] 22-07-11 01:18  Regression           INFO         --> Sample size South: 175088 -- Total sample size: 364772 -- Training fraction: 48.00%
# [000102.85] 22-07-11 01:18  Regression           INFO         --> Use k-fold training ? True
# [000102.85] 22-07-11 01:18  Regression           INFO         --> Engine: RF with params: {'n_estimators': 200, 'min_samples_leaf': 20, 'max_depth': None, 'max_leaf_nodes': None, 'n_jobs': 62, 'random_state': 123}
# [000102.87] 22-07-11 01:18  Regression           INFO         --> We use: GroupKFold(n_splits=12) k-fold with group_size = 1000.0
# [000102.90] 22-07-11 01:18  Regression           INFO         --> Train and eval for the fold:
# [000102.90] 22-07-11 01:18  Regression           INFO             * 0
# [000102.91] 22-07-11 01:18  Regression           INFO               --> There are 159490 pixels to train fold 0 which contains 15598 pixels (kept for the global training)
# [000102.91] 22-07-11 01:18  Regression           INFO               --> Features are not normalized
# [000102.91] 22-07-11 01:18  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000131.23] 22-07-11 01:18  Regression           INFO             * 1
# [000131.25] 22-07-11 01:18  Regression           INFO               --> There are 159623 pixels to train fold 1 which contains 15465 pixels (kept for the global training)
# [000131.26] 22-07-11 01:18  Regression           INFO               --> Features are not normalized
# [000131.26] 22-07-11 01:18  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000159.40] 22-07-11 01:18  Regression           INFO             * 2
# [000159.42] 22-07-11 01:18  Regression           INFO               --> There are 160551 pixels to train fold 2 which contains 14537 pixels (kept for the global training)
# [000159.42] 22-07-11 01:18  Regression           INFO               --> Features are not normalized
# [000159.43] 22-07-11 01:18  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000187.86] 22-07-11 01:19  Regression           INFO             * 3
# [000187.88] 22-07-11 01:19  Regression           INFO               --> There are 160291 pixels to train fold 3 which contains 14797 pixels (kept for the global training)
# [000187.88] 22-07-11 01:19  Regression           INFO               --> Features are not normalized
# [000187.89] 22-07-11 01:19  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000215.90] 22-07-11 01:19  Regression           INFO             * 4
# [000215.91] 22-07-11 01:19  Regression           INFO               --> There are 160682 pixels to train fold 4 which contains 14406 pixels (kept for the global training)
# [000215.92] 22-07-11 01:19  Regression           INFO               --> Features are not normalized
# [000215.92] 22-07-11 01:19  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000243.81] 22-07-11 01:20  Regression           INFO             * 5
# [000243.82] 22-07-11 01:20  Regression           INFO               --> There are 160630 pixels to train fold 5 which contains 14458 pixels (kept for the global training)
# [000243.83] 22-07-11 01:20  Regression           INFO               --> Features are not normalized
# [000243.83] 22-07-11 01:20  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000272.03] 22-07-11 01:20  Regression           INFO             * 6
# [000272.05] 22-07-11 01:20  Regression           INFO               --> There are 160749 pixels to train fold 6 which contains 14339 pixels (kept for the global training)
# [000272.05] 22-07-11 01:20  Regression           INFO               --> Features are not normalized
# [000272.05] 22-07-11 01:20  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000300.38] 22-07-11 01:21  Regression           INFO             * 7
# [000300.40] 22-07-11 01:21  Regression           INFO               --> There are 160794 pixels to train fold 7 which contains 14294 pixels (kept for the global training)
# [000300.41] 22-07-11 01:21  Regression           INFO               --> Features are not normalized
# [000300.41] 22-07-11 01:21  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000329.00] 22-07-11 01:21  Regression           INFO             * 8
# [000329.02] 22-07-11 01:21  Regression           INFO               --> There are 160670 pixels to train fold 8 which contains 14418 pixels (kept for the global training)
# [000329.03] 22-07-11 01:21  Regression           INFO               --> Features are not normalized
# [000329.03] 22-07-11 01:21  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000356.93] 22-07-11 01:22  Regression           INFO             * 9
# [000356.94] 22-07-11 01:22  Regression           INFO               --> There are 160622 pixels to train fold 9 which contains 14466 pixels (kept for the global training)
# [000356.95] 22-07-11 01:22  Regression           INFO               --> Features are not normalized
# [000356.95] 22-07-11 01:22  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000385.08] 22-07-11 01:22  Regression           INFO             * 10
# [000385.09] 22-07-11 01:22  Regression           INFO               --> There are 161417 pixels to train fold 10 which contains 13671 pixels (kept for the global training)
# [000385.10] 22-07-11 01:22  Regression           INFO               --> Features are not normalized
# [000385.10] 22-07-11 01:22  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000413.10] 22-07-11 01:23  Regression           INFO             * 11
# [000413.12] 22-07-11 01:23  Regression           INFO               --> There are 160449 pixels to train fold 11 which contains 14639 pixels (kept for the global training)
# [000413.12] 22-07-11 01:23  Regression           INFO               --> Features are not normalized
# [000413.12] 22-07-11 01:23  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000441.27] 22-07-11 01:23  Regression           INFO         --> Done in: 338.367 s
# [000442.07] 22-07-11 01:23  Regression           INFO       ** Des :
# [000442.09] 22-07-11 01:23  Regression           INFO         --> Sample size Des: 93355 -- Total sample size: 364772 -- Training fraction: 25.59%
# [000442.09] 22-07-11 01:23  Regression           INFO         --> Use k-fold training ? True
# [000442.09] 22-07-11 01:23  Regression           INFO         --> Engine: RF with params: {'n_estimators': 200, 'min_samples_leaf': 20, 'max_depth': None, 'max_leaf_nodes': None, 'n_jobs': 62, 'random_state': 123}
# [000442.10] 22-07-11 01:23  Regression           INFO         --> We use: GroupKFold(n_splits=6) k-fold with group_size = 1000.0
# [000442.11] 22-07-11 01:23  Regression           INFO         --> Train and eval for the fold:
# [000442.11] 22-07-11 01:23  Regression           INFO             * 0
# [000442.12] 22-07-11 01:23  Regression           INFO               --> There are 77533 pixels to train fold 0 which contains 15822 pixels (kept for the global training)
# [000442.12] 22-07-11 01:23  Regression           INFO               --> Features are not normalized
# [000442.12] 22-07-11 01:23  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000453.68] 22-07-11 01:23  Regression           INFO             * 1
# [000453.69] 22-07-11 01:23  Regression           INFO               --> There are 77429 pixels to train fold 1 which contains 15926 pixels (kept for the global training)
# [000453.70] 22-07-11 01:23  Regression           INFO               --> Features are not normalized
# [000453.70] 22-07-11 01:23  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000465.56] 22-07-11 01:24  Regression           INFO             * 2
# [000465.57] 22-07-11 01:24  Regression           INFO               --> There are 77447 pixels to train fold 2 which contains 15908 pixels (kept for the global training)
# [000465.57] 22-07-11 01:24  Regression           INFO               --> Features are not normalized
# [000465.58] 22-07-11 01:24  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000477.58] 22-07-11 01:24  Regression           INFO             * 3
# [000477.60] 22-07-11 01:24  Regression           INFO               --> There are 77445 pixels to train fold 3 which contains 15910 pixels (kept for the global training)
# [000477.60] 22-07-11 01:24  Regression           INFO               --> Features are not normalized
# [000477.60] 22-07-11 01:24  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000489.10] 22-07-11 01:24  Regression           INFO             * 4
# [000489.11] 22-07-11 01:24  Regression           INFO               --> There are 78424 pixels to train fold 4 which contains 14931 pixels (kept for the global training)
# [000489.12] 22-07-11 01:24  Regression           INFO               --> Features are not normalized
# [000489.12] 22-07-11 01:24  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000501.16] 22-07-11 01:24  Regression           INFO             * 5
# [000501.17] 22-07-11 01:24  Regression           INFO               --> There are 78497 pixels to train fold 5 which contains 14858 pixels (kept for the global training)
# [000501.18] 22-07-11 01:24  Regression           INFO               --> Features are not normalized
# [000501.18] 22-07-11 01:24  Regression           INFO               --> The training is done with sample_weight = 1/np.sqrt(Y_train)
# [000513.33] 22-07-11 01:24  Regression           INFO         --> Done in: 71.217 s
# [000515.75] 22-07-11 01:24  PhotoWeight          INFO     Save PhotoWeight class in MOCKS_LRG0_imaging_weight_256.npy

# %%
# Impact of the correction on the target distribution on the sky. After applying the weight, the density in DES region is lower as obserbed in the target density

to_plot = expected_mock_map.copy()
to_plot[to_plot == 0] = np.NaN
plot_moll(hp.ud_grade(to_plot, 64, order_in='NESTED'), galactic_plane=True, sgr_plane=True, min=500, max=1000, figsize=(7, 5), title='Mock without sys. cont.')

to_plot = cont_mock_map.copy()
to_plot[to_plot == 0] = np.NaN
plot_moll(hp.ud_grade(to_plot, 64, order_in='NESTED'), galactic_plane=True, sgr_plane=True, min=500, max=1000, figsize=(7, 5), title='Contaminated Mock')

to_plot = cont_mock_map.copy() * wsys_new.map
to_plot[to_plot == 0] = np.NaN
plot_moll(hp.ud_grade(to_plot, 64, order_in='NESTED'), galactic_plane=True, sgr_plane=True, min=500, max=1000, figsize=(7, 5), title='Cont + w sys Mock')

# %%
# We compare the weight from data used to contaminated mock and the computed weight from Mock
plot_moll(hp.ud_grade(wsys.map, 64, order_in='NESTED'), galactic_plane=True, sgr_plane=True, min=0.8, max=1.2, figsize=(7, 5), label='wsys from data')
plot_moll(hp.ud_grade(wsys_new.map, 64, order_in='NESTED'), galactic_plane=True, sgr_plane=True, min=0.8, max=1.2, figsize=(7, 5), label='wsys new from mocks')

# %%
# Compare imaging systematic weight estimated from the data and those estimated from mocks:
ratio = wsys.map / wsys_new.map 

plt.figure(figsize=(6.55, 4))
plt.hist(ratio, bins=100, range=(0.8, 1.2), label='wsys_data/wsys_mocks')
plt.legend()
plt.show()

plot_moll(ratio, galactic_plane=True, sgr_plane=True, min=0.9, max=1.1, figsize=(7, 5), label='ratio')

# %%
# Systematic plots

print("\nThe systematic plots computed from real data are available for LRG in img directory\n")

with np.errstate(invalid='ignore'): # avoid error with nan values 
    plot_systematic_from_map([dataframe.targets, dataframe.targets*wsys.map, dataframe.targets*wsys_new.map, expected_mock_map], 
                             ['Contaminated mocks', 'With correction from data', 'With correction from mocks', 'Uncontaminated mocks'], 
                              dataframe.fracarea, dataframe.footprint, dataframe.features, dataframe.pixels, regions=dataframe.regions,
                              ax_lim=0.2, legend_title=True, hist_legend=False, cut_fracarea=True, limits_fracarea=(0.9, 1.1), show=True, save=False, savedir='')
# Out:
# The systematic plots computed from real data are available for LRG in img directory
#
# [000532.31] 22-07-11 01:25  Systematics          INFO     Work with North
# [000533.02] 22-07-11 01:25  Systematics          INFO     Keep only pixels with fracarea > 0
# [000533.03] 22-07-11 01:25  Systematics          INFO     Keep only pixels with 0.9 < fracarea < 1.1
# [000536.64] 22-07-11 01:25  Systematics          INFO     Work with South
# [000537.37] 22-07-11 01:25  Systematics          INFO     Keep only pixels with fracarea > 0
# [000537.37] 22-07-11 01:25  Systematics          INFO     Keep only pixels with 0.9 < fracarea < 1.1
# [000541.74] 22-07-11 01:25  Systematics          INFO     Work with Des
# [000542.44] 22-07-11 01:25  Systematics          INFO     Keep only pixels with fracarea > 0
# [000542.44] 22-07-11 01:25  Systematics          INFO     Keep only pixels with 0.9 < fracarea < 1.1

# %%
# Compare real data to contaminated mock:

data_map = np.load(os.path.join(data_dir, f'SV3_{tracer}_256.npy'))

with np.errstate(invalid='ignore'): # avoid error with nan values 
    plot_systematic_from_map([data_map, dataframe.targets], 
                             ['Real data', 'Contaminated mock'], 
                              dataframe.fracarea, dataframe.footprint, dataframe.features, dataframe.pixels, regions=dataframe.regions,
                              ax_lim=0.1, cut_fracarea=True, limits_fracarea=(0.9, 1.1), legend_title=True, show=True, save=False)
# Out:
# [000545.88] 22-07-11 01:25  Systematics          INFO     Work with North
# [000546.56] 22-07-11 01:25  Systematics          INFO     Keep only pixels with fracarea > 0
# [000546.56] 22-07-11 01:25  Systematics          INFO     Keep only pixels with 0.9 < fracarea < 1.1
# [000549.38] 22-07-11 01:25  Systematics          INFO     Work with South
# [000550.10] 22-07-11 01:25  Systematics          INFO     Keep only pixels with fracarea > 0
# [000550.10] 22-07-11 01:25  Systematics          INFO     Keep only pixels with 0.9 < fracarea < 1.1
# [000553.28] 22-07-11 01:25  Systematics          INFO     Work with Des
# [000553.96] 22-07-11 01:25  Systematics          INFO     Keep only pixels with fracarea > 0
# [000553.96] 22-07-11 01:25  Systematics          INFO     Keep only pixels with 0.9 < fracarea < 1.1

# %% [markdown]
# -----
#
# ## Compute angular correlation function:
#
# **Requirements:** ``pycorr`` (https://github.com/cosmodesi/pycorr) (installation is straight forward following the doc.)

# %%
from pycorr import TwoPointCorrelationFunction, LandySzalayTwoPointEstimator, KMeansSubsampler

# %%
def get_ra_dec(nside):
    ra, dec = hp.pix2ang(nside, np.arange(hp.nside2npix(nside)), nest=True, lonlat=True)
    return ra, dec

def compute_theoritical_error(result):
    Gp = result.R1R2.normalized_wcounts()
    ND = result.D1D2.positions1[0].size
    xi_v = np.nansum(Gp*result.corr) # le 
    d = (result.corr + 1.) / (xi_v + 1.) # eq. 48
    p = 2./(Gp * ND * (ND - 1)) # eq. 43
    return d * p**0.5

def compute_angular_correlation(pix_data, pix_randoms, ra_pix, dec_pix, pix_selected, suffixe, 
                                sys_weight_map=None, edges=None, n_jackkniffe=20,
                                return_result=False, return_plot=False, save_result=False):
    """
    Remark: 
        * Error estimation with Jackknife increase the computation speed (TwoPointCorrelationFunction step) by a factor higher than ~2.
        * In the case of Target LRG in DES n_jackknife = 5 give already correct estimation of the error ! (obvisouly n_jackknife will depends on the region)
    """
    if edges is None:
        logger.info('Use default edges: np.geomspace(1e-1, 10, 25)')
        edges = np.geomspace(1e-1, 10, 25)
        
    if sys_weight_map is not None:
        logger.info('Apply systematic weights')
        pix_data_weight = pix_data*sys_weight_map
    else:
        pix_data_weight = pix_data
        
    if n_jackkniffe is not None:
        # for the Jackniffe errors: Initialize KMeansSubsampler with data or random positions -> should have no impact.
        subsampler = KMeansSubsampler(mode='angular', positions=[ra_pix[pix_selected], dec_pix[pix_selected]], nsamples=n_jackkniffe, nside=512, random_state=42, position_type='rd')
        data_labels = randoms_labels = subsampler.label([ra_pix[pix_selected], dec_pix[pix_selected]])
    else:
        data_labels = randoms_labels = None
        
    import time
    start = time.time()    
    result = TwoPointCorrelationFunction('theta', edges, 
                                         data_positions1=[ra_pix[pix_selected], dec_pix[pix_selected]], 
                                         data_weights1=pix_data_weight[pix_selected], 
                                         data_samples1=data_labels,
                                         randoms_positions1=[ra_pix[pix_selected], dec_pix[pix_selected]], 
                                         randoms_weights1=pix_randoms[pix_selected], 
                                         randoms_samples1=randoms_labels,
                                         engine='corrfunc', isa='fastest', nthreads=48)
    logger.info(f"It takes: {time.time()-start}")
    
    if save_result:
        output = f'PYCORR/LRG_{suffixe}.npy'
        result.save(output)
    
    if return_result:
        return result
    
    if return_plot:
        if n_jackkniffe is None:
            return result.sep, result.corr, compute_theoritical_error(result)
        else: 
            return result.sep, result.corr, np.diag(result.cov())**0.5

# %%
nside_corr = 256

# footprint at correct nside
DR9 = DR9Footprint(nside=nside_corr, mask_lmc=False, clear_south=True, mask_around_des=True, cut_desi=False)

# build ra, dec position of the each pixel
ra_pix, dec_pix = get_ra_dec(nside_corr)

# collect randoms
if tracer == 'LRG':
    randoms_path = '/global/cfs/cdirs/desi/cosmosim/FirstGenMocks/AbacusSummit/CutSky/LRG/z0.800/cutsky_LRG_random_S1000_1X.fits'
elif tracer == 'QSO':
    randoms_path = '/global/cfs/cdirs/desi/cosmosim/FirstGenMocks/AbacusSummit/CutSky/QSO/z1.400/cutsky_QSO_random_S1000_1X.fits'
logger.info(f'Load randoms: {randoms_path}')
randoms = fitsio.FITS(randoms_path)[1].read()
# keep only randoms with correct n(z) distribution (need for power spectrum measurement)
randoms = randoms[randoms['STATUS'] & 2**0 != 0]
logger.info('Build random healpix map...')
randoms_pix, randoms_pix_number = build_healpix_map(nside_corr, randoms['RA'], randoms['DEC'], return_pix=True)

logger.info('Build uncontaminated mock healpix map...')
mock_uncont = mock[sel_nz&is_in_wsys_footprint]
mock_uncont_pix, mock_uncont_pix_number = build_healpix_map(nside_corr, mock_uncont['RA'], mock_uncont['DEC'], return_pix=True)
logger.info('Build contaminated mock healpix map...')
mock_cont = mock[is_for_wsys_cont]
mock_cont_pix, mock_cont_pix_number = build_healpix_map(nside_corr, mock_cont['RA'], mock_cont['DEC'], return_pix=True)

wsys_pix = hp.ud_grade(wsys_new.map, nside_corr, order_in='nested')
wsys_for_cont_pix = hp.ud_grade(wsys.map, nside_corr, order_in='nested')
# Out:
# [000556.88] 22-07-11 01:25  Footprint            INFO     Load DR9 footprint with mask_lmc=False, clear_south=True, mask_around_des=True and cut_desi=False
# [000556.94] 22-07-11 01:25  Notebook             INFO     Load randoms: /global/cfs/cdirs/desi/cosmosim/FirstGenMocks/AbacusSummit/CutSky/LRG/z0.800/cutsky_LRG_random_S1000_1X.fits
# [000563.46] 22-07-11 01:25  Notebook             INFO     Build random healpix map...
# [000566.00] 22-07-11 01:25  Notebook             INFO     Build uncontaminated mock healpix map...
# [000569.52] 22-07-11 01:25  Notebook             INFO     Build contaminated mock healpix map...

# %%
regions = ['north', 'south', 'des']

for i, region in enumerate(regions):
    fig, axs = plt.subplots(1, 2, figsize=(12, 5))
    
    theta, w, err_w = compute_angular_correlation(mock_uncont_pix, randoms_pix, ra_pix, dec_pix, DR9(region), region, sys_weight_map=None, return_plot=True)
    ax = axs[0]
    ax.errorbar(theta, w, err_w, marker='o', ls=':', c='black', label=region)
    ax = axs[1]
    ax.errorbar(theta, theta**2*w, theta**2*err_w, marker='o', ls=':', c='black', label=region)  
    
#    theta, w, err_w = compute_angular_correlation(mock_cont_pix, randoms_pix, ra_pix, dec_pix, DR9(region), region, sys_weight_map=None, return_plot=True)
#    ax = axs[0]
#    ax.errorbar(theta, w, err_w, marker='x', ls='--', c='red', label=region+' + cont')
#    ax = axs[1]
#    ax.errorbar(theta, theta**2*w, theta**2*err_w, marker='x', ls='-.', c='red', label=region+' + cont')   
    
    theta, w, err_w = compute_angular_correlation(mock_cont_pix, randoms_pix, ra_pix, dec_pix, DR9(region), region, sys_weight_map=wsys_pix, return_plot=True)
    ax = axs[0]
    ax.errorbar(theta, w, err_w, marker='^', ls='-.', c='green', label=region+' + cont + wsys')
    ax = axs[1]
    ax.errorbar(theta, theta**2*w, theta**2*err_w, marker='^', ls='--', c='green', label=region+' + cont + wsys')  
    
#    theta, w, err_w = compute_angular_correlation(mock_cont_pix, randoms_pix, ra_pix, dec_pix, DR9(region), region, sys_weight_map=wsys_for_cont_pix, return_plot=True)
#    ax = axs[0]
#    ax.errorbar(theta, w, err_w, marker='^', ls='-.', c='blue', label=region+' + cont + wsys used for cont')
#    ax = axs[1]
#    ax.errorbar(theta, theta**2*w, theta**2*err_w, marker='^', ls='--', c='blue', label=region+' + cont + wsys used for cont')
    
    ax = axs[0]
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_xlim(1e-1, 1e1)
    ax.set_ylim(1e-5, 1e-1)
    ax.set_xlabel(r'$\theta$ [deg]')
    ax.set_ylabel(r'$w(\theta)$')
    ax.legend()

    ax = axs[1]
    ax.set_ylim(-0.005, 0.01)
    ax.set_xlabel(r'$\theta$ [deg]')
    ax.set_ylabel(r'$\theta^2 w(\theta)$')
    ax.legend()

    fig.tight_layout()

plt.show()
# Out:
# [000572.52] 22-07-11 01:25  Notebook             INFO     Use default edges: np.geomspace(1e-1, 10, 25)
# [000577.29] 22-07-11 01:25  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_jackknife.JackknifeLandySzalayTwoPointEstimator'>.
# [000577.30] 22-07-11 01:25  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000588.07] 22-07-11 01:26  TwoPointCorrelationFunction INFO     Computing two-point counts D1R2.
# [000605.88] 22-07-11 01:26  TwoPointCorrelationFunction INFO     Computing two-point counts R1R2.
# [000616.37] 22-07-11 01:26  Notebook             INFO     It takes: 39.076127767562866
# [000617.38] 22-07-11 01:26  Notebook             INFO     Use default edges: np.geomspace(1e-1, 10, 25)
# [000617.38] 22-07-11 01:26  Notebook             INFO     Apply systematic weights
# [000632.18] 22-07-11 01:26  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_jackknife.JackknifeLandySzalayTwoPointEstimator'>.
# [000632.18] 22-07-11 01:26  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000642.57] 22-07-11 01:27  TwoPointCorrelationFunction INFO     Computing two-point counts D1R2.
# [000660.09] 22-07-11 01:27  TwoPointCorrelationFunction INFO     Computing two-point counts R1R2.
# [000670.58] 22-07-11 01:27  Notebook             INFO     It takes: 38.4038565158844
# [000671.71] 22-07-11 01:27  Notebook             INFO     Use default edges: np.geomspace(1e-1, 10, 25)
# [000688.08] 22-07-11 01:27  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_jackknife.JackknifeLandySzalayTwoPointEstimator'>.
# [000688.08] 22-07-11 01:27  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000697.37] 22-07-11 01:27  TwoPointCorrelationFunction INFO     Computing two-point counts D1R2.
# [000714.57] 22-07-11 01:28  TwoPointCorrelationFunction INFO     Computing two-point counts R1R2.
# [000724.07] 22-07-11 01:28  Notebook             INFO     It takes: 35.99908947944641
# [000724.99] 22-07-11 01:28  Notebook             INFO     Use default edges: np.geomspace(1e-1, 10, 25)
# [000724.99] 22-07-11 01:28  Notebook             INFO     Apply systematic weights
# [000742.41] 22-07-11 01:28  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_jackknife.JackknifeLandySzalayTwoPointEstimator'>.
# [000742.41] 22-07-11 01:28  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000751.68] 22-07-11 01:28  TwoPointCorrelationFunction INFO     Computing two-point counts D1R2.
# [000768.79] 22-07-11 01:29  TwoPointCorrelationFunction INFO     Computing two-point counts R1R2.
# [000777.99] 22-07-11 01:29  Notebook             INFO     It takes: 35.60395407676697
# [000779.23] 22-07-11 01:29  Notebook             INFO     Use default edges: np.geomspace(1e-1, 10, 25)
# [000790.77] 22-07-11 01:29  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_jackknife.JackknifeLandySzalayTwoPointEstimator'>.
# [000790.77] 22-07-11 01:29  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000800.17] 22-07-11 01:29  TwoPointCorrelationFunction INFO     Computing two-point counts D1R2.
# [000816.27] 22-07-11 01:29  TwoPointCorrelationFunction INFO     Computing two-point counts R1R2.
# [000825.28] 22-07-11 01:30  Notebook             INFO     It takes: 34.51775407791138
# [000826.30] 22-07-11 01:30  Notebook             INFO     Use default edges: np.geomspace(1e-1, 10, 25)
# [000826.30] 22-07-11 01:30  Notebook             INFO     Apply systematic weights
# [000837.78] 22-07-11 01:30  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_jackknife.JackknifeLandySzalayTwoPointEstimator'>.
# [000837.78] 22-07-11 01:30  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000847.07] 22-07-11 01:30  TwoPointCorrelationFunction INFO     Computing two-point counts D1R2.
# [000862.18] 22-07-11 01:30  TwoPointCorrelationFunction INFO     Computing two-point counts R1R2.
# [000870.66] 22-07-11 01:30  Notebook             INFO     It takes: 32.898470401763916

# %%
# Draw the patch for jackkniffe error estimation:

regions = ['north', 'south', 'des']
cmap = ['viridis', 'OrRd', 'PuBu'] 
plt.figure(figsize=(7, 5))

for i, region in enumerate(regions):
    subsampler = KMeansSubsampler(mode='angular', positions=[ra_pix[DR9(region)], dec_pix[DR9(region)]], nsamples=40, nside=512, random_state=42, position_type='rd')

    plt.scatter(ra_pix[DR9(region)], dec_pix[DR9(region)], c=subsampler.label([ra_pix[DR9(region)], dec_pix[DR9(region)]]), cmap=cmap[i])
plt.xlabel('R.A. [deg]')
plt.ylabel('Dec. [deg]')

plt.tight_layout()
plt.show()

# %%
# Plot jackknife error estimation as a function of number of jackkniffe regions used:

regions = ['North', 'South', 'Des']

fig, axs = plt.subplots(1, len(regions), figsize=(5*len(regions), 4))

for i, region in enumerate(regions):
    ax = axs[i]
    
    for n_jack in [2, 5, 10, 20, 40]:
        theta, w, err_w = compute_angular_correlation(mock_cont_pix, randoms_pix, ra_pix, dec_pix, DR9(region), region, return_plot=True, n_jackkniffe=n_jack)
        ax.plot(theta, err_w, label=n_jack)
    
    ax.legend(title=region)
    ax.set_xscale('log')
    ax.set_yscale('log')
    ax.set_xlabel(r'$\theta$ [deg]')
    ax.set_ylabel(r'$\sigma_{JK}(w)(\theta)$')
    
plt.tight_layout()
plt.savefig('jackniffe_error.pdf')
plt.show()
# Out:
# [000968.90] 22-07-11 01:32  Notebook             INFO     Use default edges: np.geomspace(1e-1, 10, 25)
# [000969.77] 22-07-11 01:32  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_jackknife.JackknifeLandySzalayTwoPointEstimator'>.
# [000969.77] 22-07-11 01:32  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000972.28] 22-07-11 01:32  TwoPointCorrelationFunction INFO     Computing two-point counts D1R2.
# [000976.99] 22-07-11 01:32  TwoPointCorrelationFunction INFO     Computing two-point counts R1R2.
# [000979.57] 22-07-11 01:32  Notebook             INFO     It takes: 9.803325891494751
# [000980.41] 22-07-11 01:32  Notebook             INFO     Use default edges: np.geomspace(1e-1, 10, 25)
# [000983.20] 22-07-11 01:32  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_jackknife.JackknifeLandySzalayTwoPointEstimator'>.
# [000983.26] 22-07-11 01:32  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [000986.77] 22-07-11 01:32  TwoPointCorrelationFunction INFO     Computing two-point counts D1R2.
# [000993.37] 22-07-11 01:32  TwoPointCorrelationFunction INFO     Computing two-point counts R1R2.
# [000996.79] 22-07-11 01:32  Notebook             INFO     It takes: 13.598829746246338
# [000997.75] 22-07-11 01:32  Notebook             INFO     Use default edges: np.geomspace(1e-1, 10, 25)
# [001003.88] 22-07-11 01:33  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_jackknife.JackknifeLandySzalayTwoPointEstimator'>.
# [001003.89] 22-07-11 01:33  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001009.38] 22-07-11 01:33  TwoPointCorrelationFunction INFO     Computing two-point counts D1R2.
# [001019.48] 22-07-11 01:33  TwoPointCorrelationFunction INFO     Computing two-point counts R1R2.
# [001024.88] 22-07-11 01:33  Notebook             INFO     It takes: 21.00313115119934
# [001025.77] 22-07-11 01:33  Notebook             INFO     Use default edges: np.geomspace(1e-1, 10, 25)
# [001039.57] 22-07-11 01:33  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_jackknife.JackknifeLandySzalayTwoPointEstimator'>.
# [001039.57] 22-07-11 01:33  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001049.89] 22-07-11 01:33  TwoPointCorrelationFunction INFO     Computing two-point counts D1R2.
# [001067.17] 22-07-11 01:34  TwoPointCorrelationFunction INFO     Computing two-point counts R1R2.
# [001077.40] 22-07-11 01:34  Notebook             INFO     It takes: 37.90384244918823
# [001078.29] 22-07-11 01:34  Notebook             INFO     Use default edges: np.geomspace(1e-1, 10, 25)
# [001101.59] 22-07-11 01:34  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_jackknife.JackknifeLandySzalayTwoPointEstimator'>.
# [001101.60] 22-07-11 01:34  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001117.67] 22-07-11 01:34  TwoPointCorrelationFunction INFO     Computing two-point counts D1R2.
# [001144.79] 22-07-11 01:35  TwoPointCorrelationFunction INFO     Computing two-point counts R1R2.
# [001160.67] 22-07-11 01:35  Notebook             INFO     It takes: 59.08117699623108
# [001161.49] 22-07-11 01:35  Notebook             INFO     Use default edges: np.geomspace(1e-1, 10, 25)
# [001162.41] 22-07-11 01:35  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_jackknife.JackknifeLandySzalayTwoPointEstimator'>.
# [001162.41] 22-07-11 01:35  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001165.61] 22-07-11 01:35  TwoPointCorrelationFunction INFO     Computing two-point counts D1R2.
# [001171.70] 22-07-11 01:35  TwoPointCorrelationFunction INFO     Computing two-point counts R1R2.
# [001174.81] 22-07-11 01:35  Notebook             INFO     It takes: 12.411375761032104
# [001175.79] 22-07-11 01:35  Notebook             INFO     Use default edges: np.geomspace(1e-1, 10, 25)
# [001178.60] 22-07-11 01:35  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_jackknife.JackknifeLandySzalayTwoPointEstimator'>.
# [001178.61] 22-07-11 01:35  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001182.87] 22-07-11 01:36  TwoPointCorrelationFunction INFO     Computing two-point counts D1R2.
# [001190.99] 22-07-11 01:36  TwoPointCorrelationFunction INFO     Computing two-point counts R1R2.
# [001195.27] 22-07-11 01:36  Notebook             INFO     It takes: 16.6726815700531
# [001196.15] 22-07-11 01:36  Notebook             INFO     Use default edges: np.geomspace(1e-1, 10, 25)
# [001202.61] 22-07-11 01:36  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_jackknife.JackknifeLandySzalayTwoPointEstimator'>.
# [001202.61] 22-07-11 01:36  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001208.58] 22-07-11 01:36  TwoPointCorrelationFunction INFO     Computing two-point counts D1R2.
# [001219.88] 22-07-11 01:36  TwoPointCorrelationFunction INFO     Computing two-point counts R1R2.
# [001225.79] 22-07-11 01:36  Notebook             INFO     It takes: 23.2119779586792
# [001226.67] 22-07-11 01:36  Notebook             INFO     Use default edges: np.geomspace(1e-1, 10, 25)
# [001243.20] 22-07-11 01:37  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_jackknife.JackknifeLandySzalayTwoPointEstimator'>.
# [001243.20] 22-07-11 01:37  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001252.47] 22-07-11 01:37  TwoPointCorrelationFunction INFO     Computing two-point counts D1R2.
# [001269.68] 22-07-11 01:37  TwoPointCorrelationFunction INFO     Computing two-point counts R1R2.
# [001279.18] 22-07-11 01:37  Notebook             INFO     It takes: 35.99344229698181
# [001280.07] 22-07-11 01:37  Notebook             INFO     Use default edges: np.geomspace(1e-1, 10, 25)
# [001308.20] 22-07-11 01:38  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_jackknife.JackknifeLandySzalayTwoPointEstimator'>.
# [001308.20] 22-07-11 01:38  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001328.88] 22-07-11 01:38  TwoPointCorrelationFunction INFO     Computing two-point counts D1R2.
# [001363.07] 22-07-11 01:39  TwoPointCorrelationFunction INFO     Computing two-point counts R1R2.
# [001383.90] 22-07-11 01:39  Notebook             INFO     It takes: 75.70912528038025
# [001384.82] 22-07-11 01:39  Notebook             INFO     Use default edges: np.geomspace(1e-1, 10, 25)
# [001385.98] 22-07-11 01:39  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_jackknife.JackknifeLandySzalayTwoPointEstimator'>.
# [001385.98] 22-07-11 01:39  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001388.08] 22-07-11 01:39  TwoPointCorrelationFunction INFO     Computing two-point counts D1R2.
# [001392.08] 22-07-11 01:39  TwoPointCorrelationFunction INFO     Computing two-point counts R1R2.
# [001394.19] 22-07-11 01:39  Notebook             INFO     It takes: 8.210818767547607
# [001395.04] 22-07-11 01:39  Notebook             INFO     Use default edges: np.geomspace(1e-1, 10, 25)
# [001399.28] 22-07-11 01:39  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_jackknife.JackknifeLandySzalayTwoPointEstimator'>.
# [001399.28] 22-07-11 01:39  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001402.39] 22-07-11 01:39  TwoPointCorrelationFunction INFO     Computing two-point counts D1R2.
# [001408.27] 22-07-11 01:39  TwoPointCorrelationFunction INFO     Computing two-point counts R1R2.
# [001411.48] 22-07-11 01:39  Notebook             INFO     It takes: 12.282441854476929
# [001412.42] 22-07-11 01:39  Notebook             INFO     Use default edges: np.geomspace(1e-1, 10, 25)
# [001418.89] 22-07-11 01:39  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_jackknife.JackknifeLandySzalayTwoPointEstimator'>.
# [001418.90] 22-07-11 01:39  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001423.48] 22-07-11 01:40  TwoPointCorrelationFunction INFO     Computing two-point counts D1R2.
# [001432.00] 22-07-11 01:40  TwoPointCorrelationFunction INFO     Computing two-point counts R1R2.
# [001436.47] 22-07-11 01:40  Notebook             INFO     It takes: 17.581855058670044
# [001437.39] 22-07-11 01:40  Notebook             INFO     Use default edges: np.geomspace(1e-1, 10, 25)
# [001448.88] 22-07-11 01:40  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_jackknife.JackknifeLandySzalayTwoPointEstimator'>.
# [001448.88] 22-07-11 01:40  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001458.37] 22-07-11 01:40  TwoPointCorrelationFunction INFO     Computing two-point counts D1R2.
# [001473.57] 22-07-11 01:40  TwoPointCorrelationFunction INFO     Computing two-point counts R1R2.
# [001482.96] 22-07-11 01:41  Notebook             INFO     It takes: 34.08616256713867
# [001483.89] 22-07-11 01:41  Notebook             INFO     Use default edges: np.geomspace(1e-1, 10, 25)
# [001510.28] 22-07-11 01:41  TwoPointCorrelationFunction INFO     Using estimator <class 'pycorr.twopoint_jackknife.JackknifeLandySzalayTwoPointEstimator'>.
# [001510.29] 22-07-11 01:41  TwoPointCorrelationFunction INFO     Computing two-point counts D1D2.
# [001524.77] 22-07-11 01:41  TwoPointCorrelationFunction INFO     Computing two-point counts D1R2.
# [001550.39] 22-07-11 01:42  TwoPointCorrelationFunction INFO     Computing two-point counts R1R2.
# [001564.89] 22-07-11 01:42  Notebook             INFO     It takes: 54.611234188079834

# %% [markdown]
# ---------
#
# ## Compute power spectrum:
#
# **Requierement**: ``pypower`` (https://github.com/adematti/pypower) and ``cosmoprimo`` (https://github.com/cosmodesi/cosmoprimo)

# %%
from pypower import CatalogFFTPower

# Set cosmology to transform redshift to distance
from cosmoprimo.fiducial import DESI
distance = DESI(engine='class').comoving_radial_distance

# %%
from wrapper import time_measurement

@time_measurement
def compute_power(data, randoms, data_weights=None, randoms_weights=None, ells=(0, 2, 4), edges=None, return_plot=False):
    if edges is None:
        logger.info('Use default edges: np.linspace(0, 0.3, 81)')
        edges = np.linspace(0, 0.3, 81)
    
    # set data weights
    if data_weights is None:
        data_weights = np.ones(data['RA'].size)
    
    # set randoms weights
    if randoms_weights is None:
        randoms_weights = np.ones(randoms['RA'].size)
    
    result = CatalogFFTPower(data_positions1=[data['RA'], data['DEC'], distance(data['Z'])], data_weights1=data_weights,
                             randoms_positions1=[randoms['RA'], randoms['DEC'], distance(randoms['Z'])], randoms_weights1=randoms_weights,
                             edges=edges, ells=ells, interlacing=2, boxsize=None, boxpad=4, nmesh=512, resampler='tsc',
                             los=None, position_type='rdd', mpiroot=0)
    if return_plot:
        return result.poles.k, result.poles

# %%
regions = ['North', 'South', 'Des']
z_min, z_max = 0.4, 0.6

plt.figure(figsize=(14, 15))
j = 0
for region in regions:
    sel_in_randoms = DR9(region)[randoms_pix_number] & (randoms['Z'] <= z_max) & (randoms['Z'] >= z_min) 
    sel_in_mock_uncont = DR9(region)[mock_uncont_pix_number] & (mock_uncont['Z'] <= z_max) & (mock_uncont['Z'] >= z_min) 
    sel_in_mock_cont = DR9(region)[mock_cont_pix_number] & (mock_cont['Z'] <= z_max) & (mock_cont['Z'] >= z_min) 

    k, poles = compute_power(mock_uncont[sel_in_mock_uncont], randoms[sel_in_randoms], return_plot=True)
    k2, poles2 = compute_power(mock_cont[sel_in_mock_cont], randoms[sel_in_randoms], return_plot=True)
    k3, poles3 = compute_power(mock_cont[sel_in_mock_cont], randoms[sel_in_randoms], data_weights=wsys_new(mock_cont[sel_in_mock_cont]['RA'], mock_cont[sel_in_mock_cont]['DEC']),  return_plot=True)

    plt.subplot(321+j)
    j += 1
    print(321+j)
    color = ['b', 'r', 'g']
    for i, ell in enumerate(poles.ells):
        plt.plot(k, poles(ell=ell, complex=False), marker='o', color=color[i], ls='--', label='uncont $\ell = {:d}$'.format(ell))
        plt.plot(k, poles2(ell=ell, complex=False), marker='.', color=color[i], ls=':', label='cont $\ell = {:d}$'.format(ell))
        plt.plot(k, poles3(ell=ell, complex=False), marker='x', color=color[i], ls='-', label='cont + wsys $\ell = {:d}$'.format(ell))
    plt.legend(title=region, loc='upper right')
    plt.yscale('log')
    plt.xscale('log')
    plt.ylim(4e3, 8e4)
    plt.xlabel('$k$ [$h/\mathrm{Mpc}$]')
    plt.ylabel(r'$P(k)$ [$(\mathrm{Mpc}/h)^{3}$]')

    plt.subplot(321+j)
    j+=1
    color = ['b', 'r', 'g']
    for i, ell in enumerate(poles.ells):
        plt.plot(k, k*poles(ell=ell, complex=False), marker='o', color=color[i], ls='--', label='uncont $\ell = {:d}$'.format(ell))
        plt.plot(k, k*poles2(ell=ell, complex=False), marker='.', color=color[i], ls=':', label='cont $\ell = {:d}$'.format(ell))
        plt.plot(k, k*poles3(ell=ell, complex=False), marker='x', color=color[i], ls='-', label='cont + wsys $\ell = {:d}$'.format(ell))
    #plt.legend()
    plt.xlabel('$k$ [$h/\mathrm{Mpc}$]')
    plt.ylabel(r'$kP(k)$ [$(\mathrm{Mpc}/h)^{2}$]')

plt.tight_layout()
plt.savefig('Mock_LRG_power.pdf')
plt.show()

#print('Shot noise is {:.4f}.'.format(poles.shotnoise)) # cross-correlation, shot noise is 0.
#print('Normalization is {:.4f}.'.format(poles.wnorm))
# Out:
# [001571.85] 22-07-11 01:42  Notebook             INFO     Use default edges: np.linspace(0, 0.3, 81)
# [001572.80] 22-07-11 01:42  CatalogFFTPower      INFO     Painting catalog 1 to mesh CatalogMesh(nmesh=[512 512 512], boxsize=[10279.51640823 10279.51640823 10279.51640823], boxcenter=[-465.97287548  -12.14680165 1051.77512543], dtype=float64).
# [001573.36] 22-07-11 01:42  CatalogMesh          INFO     Slab 0 ~ 4194304 / 799625.
# [001573.91] 22-07-11 01:42  CatalogMesh          INFO     Painted 799625 out of 799625 objects to mesh.
# [001573.92] 22-07-11 01:42  CatalogMesh          INFO     Slab 0 ~ 4194304 / 794925.
# [001574.46] 22-07-11 01:42  CatalogMesh          INFO     Painted 794925 out of 794925 objects to mesh.
# [001574.46] 22-07-11 01:42  CatalogMesh          INFO     Running interlacing at order 2.
# [001578.72] 22-07-11 01:42  CatalogMesh          INFO     Slab 0 ~ 4194304 / 799625.
# [001579.25] 22-07-11 01:42  CatalogMesh          INFO     Painted 799625 out of 799625 objects to mesh.
# [001579.26] 22-07-11 01:42  CatalogMesh          INFO     Slab 0 ~ 4194304 / 794925.
# [001579.78] 22-07-11 01:42  CatalogMesh          INFO     Painted 794925 out of 794925 objects to mesh.
# [001590.27] 22-07-11 01:42  CatalogFFTPower      INFO     Done painting catalog 1 to mesh.
# [001590.27] 22-07-11 01:42  CatalogFFTPower      INFO     Using 80 k-bins between 0.000 and 0.300.
# [001590.84] 22-07-11 01:42  CatalogMesh          INFO     Slab 0 ~ 4194304 / 799625.
# [001591.37] 22-07-11 01:42  CatalogMesh          INFO     Painted 799625 out of 799625 objects to mesh.
# [001591.73] 22-07-11 01:42  CatalogMesh          INFO     Slab 0 ~ 4194304 / 794925.
# [001592.20] 22-07-11 01:42  CatalogMesh          INFO     Painted 794925 out of 794925 objects to mesh.
# [001592.60] 22-07-11 01:42  CatalogFFTPower      INFO     Meshes prepared in elapsed time 19.80 s.
# [001592.61] 22-07-11 01:42  CatalogFFTPower      INFO     Running mesh calculation.
# [001611.32] 22-07-11 01:43  CatalogFFTPower      INFO     ell = 0 done; 1 r2c completed
# [001645.48] 22-07-11 01:43  CatalogFFTPower      INFO     ell = 2 done; 5 r2c completed
# [001712.69] 22-07-11 01:44  CatalogFFTPower      INFO     ell = 4 done; 9 r2c completed
# [001726.88] 22-07-11 01:45  CatalogFFTPower      INFO     Mesh calculations performed in elapsed time 134.27 s.
# [001726.88] 22-07-11 01:45  CatalogFFTPower      INFO     Power spectrum computed in elapsed time 154.08 s.
# [001726.88] 22-07-11 01:45  wrapper              INFO     ----> Function "compute_power" took : 00:02:35.033 sec
# [001726.99] 22-07-11 01:45  Notebook             INFO     Use default edges: np.linspace(0, 0.3, 81)
# [001727.82] 22-07-11 01:45  CatalogFFTPower      INFO     Painting catalog 1 to mesh CatalogMesh(nmesh=[512 512 512], boxsize=[10279.51640823 10279.51640823 10279.51640823], boxcenter=[-465.97287548  -12.14680165 1051.77512543], dtype=float64).
# [001728.36] 22-07-11 01:45  CatalogMesh          INFO     Slab 0 ~ 4194304 / 607747.
# [001728.82] 22-07-11 01:45  CatalogMesh          INFO     Painted 607747 out of 607747 objects to mesh.
# [001728.83] 22-07-11 01:45  CatalogMesh          INFO     Slab 0 ~ 4194304 / 794925.
# [001729.35] 22-07-11 01:45  CatalogMesh          INFO     Painted 794925 out of 794925 objects to mesh.
# [001729.35] 22-07-11 01:45  CatalogMesh          INFO     Running interlacing at order 2.
# [001733.53] 22-07-11 01:45  CatalogMesh          INFO     Slab 0 ~ 4194304 / 607747.
# [001733.94] 22-07-11 01:45  CatalogMesh          INFO     Painted 607747 out of 607747 objects to mesh.
# [001733.95] 22-07-11 01:45  CatalogMesh          INFO     Slab 0 ~ 4194304 / 794925.
# [001734.48] 22-07-11 01:45  CatalogMesh          INFO     Painted 794925 out of 794925 objects to mesh.
# [001745.00] 22-07-11 01:45  CatalogFFTPower      INFO     Done painting catalog 1 to mesh.
# [001745.00] 22-07-11 01:45  CatalogFFTPower      INFO     Using 80 k-bins between 0.000 and 0.300.
# [001745.50] 22-07-11 01:45  CatalogMesh          INFO     Slab 0 ~ 4194304 / 607747.
# [001745.95] 22-07-11 01:45  CatalogMesh          INFO     Painted 607747 out of 607747 objects to mesh.
# [001746.28] 22-07-11 01:45  CatalogMesh          INFO     Slab 0 ~ 4194304 / 794925.
# [001746.74] 22-07-11 01:45  CatalogMesh          INFO     Painted 794925 out of 794925 objects to mesh.
# [001747.15] 22-07-11 01:45  CatalogFFTPower      INFO     Meshes prepared in elapsed time 19.33 s.
# [001747.15] 22-07-11 01:45  CatalogFFTPower      INFO     Running mesh calculation.
# [001765.86] 22-07-11 01:45  CatalogFFTPower      INFO     ell = 0 done; 1 r2c completed
# [001798.21] 22-07-11 01:46  CatalogFFTPower      INFO     ell = 2 done; 5 r2c completed
# [001866.92] 22-07-11 01:47  CatalogFFTPower      INFO     ell = 4 done; 9 r2c completed
# [001882.76] 22-07-11 01:47  CatalogFFTPower      INFO     Mesh calculations performed in elapsed time 135.62 s.
# [001882.76] 22-07-11 01:47  CatalogFFTPower      INFO     Power spectrum computed in elapsed time 154.94 s.
# [001882.77] 22-07-11 01:47  wrapper              INFO     ----> Function "compute_power" took : 00:02:35.774 sec
# [001882.97] 22-07-11 01:47  Notebook             INFO     Use default edges: np.linspace(0, 0.3, 81)
# [001883.78] 22-07-11 01:47  CatalogFFTPower      INFO     Painting catalog 1 to mesh CatalogMesh(nmesh=[512 512 512], boxsize=[10279.51640823 10279.51640823 10279.51640823], boxcenter=[-465.97287548  -12.14680165 1051.77512543], dtype=float64).
# [001884.32] 22-07-11 01:47  CatalogMesh          INFO     Slab 0 ~ 4194304 / 607747.
# [001884.79] 22-07-11 01:47  CatalogMesh          INFO     Painted 607747 out of 607747 objects to mesh.
# [001884.80] 22-07-11 01:47  CatalogMesh          INFO     Slab 0 ~ 4194304 / 794925.
# [001885.33] 22-07-11 01:47  CatalogMesh          INFO     Painted 794925 out of 794925 objects to mesh.
# [001885.33] 22-07-11 01:47  CatalogMesh          INFO     Running interlacing at order 2.
# [001889.47] 22-07-11 01:47  CatalogMesh          INFO     Slab 0 ~ 4194304 / 607747.
# [001889.89] 22-07-11 01:47  CatalogMesh          INFO     Painted 607747 out of 607747 objects to mesh.
# [001889.90] 22-07-11 01:47  CatalogMesh          INFO     Slab 0 ~ 4194304 / 794925.
# [001890.47] 22-07-11 01:47  CatalogMesh          INFO     Painted 794925 out of 794925 objects to mesh.
# [001901.28] 22-07-11 01:48  CatalogFFTPower      INFO     Done painting catalog 1 to mesh.
# [001901.28] 22-07-11 01:48  CatalogFFTPower      INFO     Using 80 k-bins between 0.000 and 0.300.
# [001901.78] 22-07-11 01:48  CatalogMesh          INFO     Slab 0 ~ 4194304 / 607747.
# [001902.28] 22-07-11 01:48  CatalogMesh          INFO     Painted 607747 out of 607747 objects to mesh.
# [001902.62] 22-07-11 01:48  CatalogMesh          INFO     Slab 0 ~ 4194304 / 794925.
# [001903.11] 22-07-11 01:48  CatalogMesh          INFO     Painted 794925 out of 794925 objects to mesh.
# [001903.55] 22-07-11 01:48  CatalogFFTPower      INFO     Meshes prepared in elapsed time 19.78 s.
# [001903.55] 22-07-11 01:48  CatalogFFTPower      INFO     Running mesh calculation.
# [001926.75] 22-07-11 01:48  CatalogFFTPower      INFO     ell = 0 done; 1 r2c completed
# [001959.78] 22-07-11 01:48  CatalogFFTPower      INFO     ell = 2 done; 5 r2c completed
# [002027.48] 22-07-11 01:50  CatalogFFTPower      INFO     ell = 4 done; 9 r2c completed
# [002041.51] 22-07-11 01:50  CatalogFFTPower      INFO     Mesh calculations performed in elapsed time 137.95 s.
# [002041.51] 22-07-11 01:50  CatalogFFTPower      INFO     Power spectrum computed in elapsed time 157.73 s.
# [002041.51] 22-07-11 01:50  wrapper              INFO     ----> Function "compute_power" took : 00:02:38.539 sec
# 322
# [002045.34] 22-07-11 01:50  Notebook             INFO     Use default edges: np.linspace(0, 0.3, 81)
# [002047.21] 22-07-11 01:50  CatalogFFTPower      INFO     Painting catalog 1 to mesh CatalogMesh(nmesh=[512 512 512], boxsize=[12271.33452906 12271.33452906 12271.33452906], boxcenter=[ -0.78028605  -9.42810737 213.09429547], dtype=float64).
# [002047.79] 22-07-11 01:50  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1480144.
# [002048.70] 22-07-11 01:50  CatalogMesh          INFO     Painted 1480144 out of 1480144 objects to mesh.
# [002048.73] 22-07-11 01:50  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1473145.
# [002049.60] 22-07-11 01:50  CatalogMesh          INFO     Painted 1473145 out of 1473145 objects to mesh.
# [002049.61] 22-07-11 01:50  CatalogMesh          INFO     Running interlacing at order 2.
# [002053.76] 22-07-11 01:50  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1480144.
# [002054.59] 22-07-11 01:50  CatalogMesh          INFO     Painted 1480144 out of 1480144 objects to mesh.
# [002054.61] 22-07-11 01:50  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1473145.
# [002055.48] 22-07-11 01:50  CatalogMesh          INFO     Painted 1473145 out of 1473145 objects to mesh.
# [002065.88] 22-07-11 01:50  CatalogFFTPower      INFO     Done painting catalog 1 to mesh.
# [002065.88] 22-07-11 01:50  CatalogFFTPower      INFO     Using 80 k-bins between 0.000 and 0.300.
# [002066.87] 22-07-11 01:50  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1480144.
# [002067.67] 22-07-11 01:50  CatalogMesh          INFO     Painted 1480144 out of 1480144 objects to mesh.
# [002068.36] 22-07-11 01:50  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1473145.
# [002069.16] 22-07-11 01:50  CatalogMesh          INFO     Painted 1473145 out of 1473145 objects to mesh.
# [002069.90] 22-07-11 01:50  CatalogFFTPower      INFO     Meshes prepared in elapsed time 22.69 s.
# [002069.90] 22-07-11 01:50  CatalogFFTPower      INFO     Running mesh calculation.
# [002088.78] 22-07-11 01:51  CatalogFFTPower      INFO     ell = 0 done; 1 r2c completed
# [002120.94] 22-07-11 01:51  CatalogFFTPower      INFO     ell = 2 done; 5 r2c completed
# [002187.92] 22-07-11 01:52  CatalogFFTPower      INFO     ell = 4 done; 9 r2c completed
# [002201.66] 22-07-11 01:53  CatalogFFTPower      INFO     Mesh calculations performed in elapsed time 131.77 s.
# [002201.66] 22-07-11 01:53  CatalogFFTPower      INFO     Power spectrum computed in elapsed time 154.45 s.
# [002201.67] 22-07-11 01:53  wrapper              INFO     ----> Function "compute_power" took : 00:02:36.329 sec
# [002201.88] 22-07-11 01:53  Notebook             INFO     Use default edges: np.linspace(0, 0.3, 81)
# [002203.46] 22-07-11 01:53  CatalogFFTPower      INFO     Painting catalog 1 to mesh CatalogMesh(nmesh=[512 512 512], boxsize=[12271.33452906 12271.33452906 12271.33452906], boxcenter=[ -0.78028605  -9.4955291  213.09429547], dtype=float64).
# [002204.01] 22-07-11 01:53  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1136408.
# [002204.72] 22-07-11 01:53  CatalogMesh          INFO     Painted 1136408 out of 1136408 objects to mesh.
# [002204.73] 22-07-11 01:53  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1473145.
# [002205.60] 22-07-11 01:53  CatalogMesh          INFO     Painted 1473145 out of 1473145 objects to mesh.
# [002205.61] 22-07-11 01:53  CatalogMesh          INFO     Running interlacing at order 2.
# [002209.60] 22-07-11 01:53  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1136408.
# [002210.35] 22-07-11 01:53  CatalogMesh          INFO     Painted 1136408 out of 1136408 objects to mesh.
# [002210.37] 22-07-11 01:53  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1473145.
# [002211.22] 22-07-11 01:53  CatalogMesh          INFO     Painted 1473145 out of 1473145 objects to mesh.
# [002221.78] 22-07-11 01:53  CatalogFFTPower      INFO     Done painting catalog 1 to mesh.
# [002221.78] 22-07-11 01:53  CatalogFFTPower      INFO     Using 80 k-bins between 0.000 and 0.300.
# [002222.67] 22-07-11 01:53  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1136408.
# [002223.32] 22-07-11 01:53  CatalogMesh          INFO     Painted 1136408 out of 1136408 objects to mesh.
# [002223.94] 22-07-11 01:53  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1473145.
# [002224.81] 22-07-11 01:53  CatalogMesh          INFO     Painted 1473145 out of 1473145 objects to mesh.
# [002225.58] 22-07-11 01:53  CatalogFFTPower      INFO     Meshes prepared in elapsed time 22.12 s.
# [002225.58] 22-07-11 01:53  CatalogFFTPower      INFO     Running mesh calculation.
# [002246.59] 22-07-11 01:53  CatalogFFTPower      INFO     ell = 0 done; 1 r2c completed
# [002279.08] 22-07-11 01:54  CatalogFFTPower      INFO     ell = 2 done; 5 r2c completed
# [002343.18] 22-07-11 01:55  CatalogFFTPower      INFO     ell = 4 done; 9 r2c completed
# [002355.07] 22-07-11 01:55  CatalogFFTPower      INFO     Mesh calculations performed in elapsed time 129.49 s.
# [002355.07] 22-07-11 01:55  CatalogFFTPower      INFO     Power spectrum computed in elapsed time 151.61 s.
# [002355.08] 22-07-11 01:55  wrapper              INFO     ----> Function "compute_power" took : 00:02:33.194 sec
# [002355.48] 22-07-11 01:55  Notebook             INFO     Use default edges: np.linspace(0, 0.3, 81)
# [002356.99] 22-07-11 01:55  CatalogFFTPower      INFO     Painting catalog 1 to mesh CatalogMesh(nmesh=[512 512 512], boxsize=[12271.33452906 12271.33452906 12271.33452906], boxcenter=[ -0.78028605  -9.4955291  213.09429547], dtype=float64).
# [002357.51] 22-07-11 01:55  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1136408.
# [002358.25] 22-07-11 01:55  CatalogMesh          INFO     Painted 1136408 out of 1136408 objects to mesh.
# [002358.27] 22-07-11 01:55  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1473145.
# [002359.15] 22-07-11 01:55  CatalogMesh          INFO     Painted 1473145 out of 1473145 objects to mesh.
# [002359.16] 22-07-11 01:55  CatalogMesh          INFO     Running interlacing at order 2.
# [002362.99] 22-07-11 01:55  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1136408.
# [002363.66] 22-07-11 01:55  CatalogMesh          INFO     Painted 1136408 out of 1136408 objects to mesh.
# [002363.69] 22-07-11 01:55  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1473145.
# [002364.54] 22-07-11 01:55  CatalogMesh          INFO     Painted 1473145 out of 1473145 objects to mesh.
# [002374.32] 22-07-11 01:55  CatalogFFTPower      INFO     Done painting catalog 1 to mesh.
# [002374.32] 22-07-11 01:55  CatalogFFTPower      INFO     Using 80 k-bins between 0.000 and 0.300.
# [002375.17] 22-07-11 01:55  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1136408.
# [002375.92] 22-07-11 01:55  CatalogMesh          INFO     Painted 1136408 out of 1136408 objects to mesh.
# [002376.51] 22-07-11 01:55  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1473145.
# [002377.24] 22-07-11 01:55  CatalogMesh          INFO     Painted 1473145 out of 1473145 objects to mesh.
# [002378.00] 22-07-11 01:55  CatalogFFTPower      INFO     Meshes prepared in elapsed time 21.01 s.
# [002378.00] 22-07-11 01:55  CatalogFFTPower      INFO     Running mesh calculation.
# [002395.02] 22-07-11 01:56  CatalogFFTPower      INFO     ell = 0 done; 1 r2c completed
# [002425.94] 22-07-11 01:56  CatalogFFTPower      INFO     ell = 2 done; 5 r2c completed
# [002489.44] 22-07-11 01:57  CatalogFFTPower      INFO     ell = 4 done; 9 r2c completed
# [002501.37] 22-07-11 01:58  CatalogFFTPower      INFO     Mesh calculations performed in elapsed time 123.37 s.
# [002501.37] 22-07-11 01:58  CatalogFFTPower      INFO     Power spectrum computed in elapsed time 144.38 s.
# [002501.37] 22-07-11 01:58  wrapper              INFO     ----> Function "compute_power" took : 00:02:25.890 sec
# 324
# [002505.18] 22-07-11 01:58  Notebook             INFO     Use default edges: np.linspace(0, 0.3, 81)
# [002506.02] 22-07-11 01:58  CatalogFFTPower      INFO     Painting catalog 1 to mesh CatalogMesh(nmesh=[512 512 512], boxsize=[9950.77788531 9950.77788531 9950.77788531], boxcenter=[ 702.3360053   204.59487346 -646.29584657], dtype=float64).
# [002506.55] 22-07-11 01:58  CatalogMesh          INFO     Slab 0 ~ 4194304 / 760013.
# [002507.10] 22-07-11 01:58  CatalogMesh          INFO     Painted 760013 out of 760013 objects to mesh.
# [002507.11] 22-07-11 01:58  CatalogMesh          INFO     Slab 0 ~ 4194304 / 763444.
# [002507.56] 22-07-11 01:58  CatalogMesh          INFO     Painted 763444 out of 763444 objects to mesh.
# [002507.56] 22-07-11 01:58  CatalogMesh          INFO     Running interlacing at order 2.
# [002511.46] 22-07-11 01:58  CatalogMesh          INFO     Slab 0 ~ 4194304 / 760013.
# [002511.88] 22-07-11 01:58  CatalogMesh          INFO     Painted 760013 out of 760013 objects to mesh.
# [002511.89] 22-07-11 01:58  CatalogMesh          INFO     Slab 0 ~ 4194304 / 763444.
# [002512.34] 22-07-11 01:58  CatalogMesh          INFO     Painted 763444 out of 763444 objects to mesh.
# [002522.21] 22-07-11 01:58  CatalogFFTPower      INFO     Done painting catalog 1 to mesh.
# [002522.21] 22-07-11 01:58  CatalogFFTPower      INFO     Using 80 k-bins between 0.000 and 0.300.
# [002522.70] 22-07-11 01:58  CatalogMesh          INFO     Slab 0 ~ 4194304 / 760013.
# [002523.11] 22-07-11 01:58  CatalogMesh          INFO     Painted 760013 out of 760013 objects to mesh.
# [002523.47] 22-07-11 01:58  CatalogMesh          INFO     Slab 0 ~ 4194304 / 763444.
# [002523.89] 22-07-11 01:58  CatalogMesh          INFO     Painted 763444 out of 763444 objects to mesh.
# [002524.25] 22-07-11 01:58  CatalogFFTPower      INFO     Meshes prepared in elapsed time 18.23 s.
# [002524.25] 22-07-11 01:58  CatalogFFTPower      INFO     Running mesh calculation.
# [002540.47] 22-07-11 01:58  CatalogFFTPower      INFO     ell = 0 done; 1 r2c completed
# [002571.80] 22-07-11 01:59  CatalogFFTPower      INFO     ell = 2 done; 5 r2c completed
# [002634.12] 22-07-11 02:00  CatalogFFTPower      INFO     ell = 4 done; 9 r2c completed
# [002645.59] 22-07-11 02:00  CatalogFFTPower      INFO     Mesh calculations performed in elapsed time 121.33 s.
# [002645.59] 22-07-11 02:00  CatalogFFTPower      INFO     Power spectrum computed in elapsed time 139.57 s.
# [002645.60] 22-07-11 02:00  wrapper              INFO     ----> Function "compute_power" took : 00:02:20.413 sec
# [002645.76] 22-07-11 02:00  Notebook             INFO     Use default edges: np.linspace(0, 0.3, 81)
# [002646.48] 22-07-11 02:00  CatalogFFTPower      INFO     Painting catalog 1 to mesh CatalogMesh(nmesh=[512 512 512], boxsize=[9950.77788531 9950.77788531 9950.77788531], boxcenter=[ 702.3360053   204.59487346 -646.46672775], dtype=float64).
# [002647.02] 22-07-11 02:00  CatalogMesh          INFO     Slab 0 ~ 4194304 / 546658.
# [002647.42] 22-07-11 02:00  CatalogMesh          INFO     Painted 546658 out of 546658 objects to mesh.
# [002647.43] 22-07-11 02:00  CatalogMesh          INFO     Slab 0 ~ 4194304 / 763444.
# [002647.90] 22-07-11 02:00  CatalogMesh          INFO     Painted 763444 out of 763444 objects to mesh.
# [002647.90] 22-07-11 02:00  CatalogMesh          INFO     Running interlacing at order 2.
# [002651.79] 22-07-11 02:00  CatalogMesh          INFO     Slab 0 ~ 4194304 / 546658.
# [002652.19] 22-07-11 02:00  CatalogMesh          INFO     Painted 546658 out of 546658 objects to mesh.
# [002652.20] 22-07-11 02:00  CatalogMesh          INFO     Slab 0 ~ 4194304 / 763444.
# [002652.66] 22-07-11 02:00  CatalogMesh          INFO     Painted 763444 out of 763444 objects to mesh.
# [002662.73] 22-07-11 02:00  CatalogFFTPower      INFO     Done painting catalog 1 to mesh.
# [002662.73] 22-07-11 02:00  CatalogFFTPower      INFO     Using 80 k-bins between 0.000 and 0.300.
# [002663.17] 22-07-11 02:00  CatalogMesh          INFO     Slab 0 ~ 4194304 / 546658.
# [002663.50] 22-07-11 02:00  CatalogMesh          INFO     Painted 546658 out of 546658 objects to mesh.
# [002663.80] 22-07-11 02:00  CatalogMesh          INFO     Slab 0 ~ 4194304 / 763444.
# [002664.21] 22-07-11 02:00  CatalogMesh          INFO     Painted 763444 out of 763444 objects to mesh.
# [002664.58] 22-07-11 02:00  CatalogFFTPower      INFO     Meshes prepared in elapsed time 18.10 s.
# [002664.58] 22-07-11 02:00  CatalogFFTPower      INFO     Running mesh calculation.
# [002681.15] 22-07-11 02:01  CatalogFFTPower      INFO     ell = 0 done; 1 r2c completed
# [002712.77] 22-07-11 02:01  CatalogFFTPower      INFO     ell = 2 done; 5 r2c completed
# [002774.42] 22-07-11 02:02  CatalogFFTPower      INFO     ell = 4 done; 9 r2c completed
# [002786.35] 22-07-11 02:02  CatalogFFTPower      INFO     Mesh calculations performed in elapsed time 121.77 s.
# [002786.35] 22-07-11 02:02  CatalogFFTPower      INFO     Power spectrum computed in elapsed time 139.87 s.
# [002786.36] 22-07-11 02:02  wrapper              INFO     ----> Function "compute_power" took : 00:02:20.604 sec
# [002786.56] 22-07-11 02:02  Notebook             INFO     Use default edges: np.linspace(0, 0.3, 81)
# [002787.27] 22-07-11 02:02  CatalogFFTPower      INFO     Painting catalog 1 to mesh CatalogMesh(nmesh=[512 512 512], boxsize=[9950.77788531 9950.77788531 9950.77788531], boxcenter=[ 702.3360053   204.59487346 -646.46672775], dtype=float64).
# [002787.81] 22-07-11 02:02  CatalogMesh          INFO     Slab 0 ~ 4194304 / 546658.
# [002788.21] 22-07-11 02:02  CatalogMesh          INFO     Painted 546658 out of 546658 objects to mesh.
# [002788.22] 22-07-11 02:02  CatalogMesh          INFO     Slab 0 ~ 4194304 / 763444.
# [002788.67] 22-07-11 02:02  CatalogMesh          INFO     Painted 763444 out of 763444 objects to mesh.
# [002788.67] 22-07-11 02:02  CatalogMesh          INFO     Running interlacing at order 2.
# [002792.57] 22-07-11 02:02  CatalogMesh          INFO     Slab 0 ~ 4194304 / 546658.
# [002792.94] 22-07-11 02:02  CatalogMesh          INFO     Painted 546658 out of 546658 objects to mesh.
# [002792.95] 22-07-11 02:02  CatalogMesh          INFO     Slab 0 ~ 4194304 / 763444.
# [002793.43] 22-07-11 02:02  CatalogMesh          INFO     Painted 763444 out of 763444 objects to mesh.
# [002803.22] 22-07-11 02:03  CatalogFFTPower      INFO     Done painting catalog 1 to mesh.
# [002803.23] 22-07-11 02:03  CatalogFFTPower      INFO     Using 80 k-bins between 0.000 and 0.300.
# [002803.70] 22-07-11 02:03  CatalogMesh          INFO     Slab 0 ~ 4194304 / 546658.
# [002804.11] 22-07-11 02:03  CatalogMesh          INFO     Painted 546658 out of 546658 objects to mesh.
# [002804.42] 22-07-11 02:03  CatalogMesh          INFO     Slab 0 ~ 4194304 / 763444.
# [002804.87] 22-07-11 02:03  CatalogMesh          INFO     Painted 763444 out of 763444 objects to mesh.
# [002805.31] 22-07-11 02:03  CatalogFFTPower      INFO     Meshes prepared in elapsed time 18.04 s.
# [002805.31] 22-07-11 02:03  CatalogFFTPower      INFO     Running mesh calculation.
# [002821.90] 22-07-11 02:03  CatalogFFTPower      INFO     ell = 0 done; 1 r2c completed
# [002852.38] 22-07-11 02:03  CatalogFFTPower      INFO     ell = 2 done; 5 r2c completed
# [002915.00] 22-07-11 02:04  CatalogFFTPower      INFO     ell = 4 done; 9 r2c completed
# [002926.81] 22-07-11 02:05  CatalogFFTPower      INFO     Mesh calculations performed in elapsed time 121.50 s.
# [002926.81] 22-07-11 02:05  CatalogFFTPower      INFO     Power spectrum computed in elapsed time 139.54 s.
# [002926.82] 22-07-11 02:05  wrapper              INFO     ----> Function "compute_power" took : 00:02:20.260 sec
# 326

# %%
regions = ['North', 'South', 'Des']
z_min, z_max = 0.4, 0.6

plt.figure(figsize=(15, 5))
j = 0
for region in regions:
    sel_in_randoms = DR9(region)[randoms_pix_number] & (randoms['Z'] <= z_max) & (randoms['Z'] >= z_min) 
    sel_in_mock_uncont = DR9(region)[mock_uncont_pix_number] & (mock_uncont['Z'] <= z_max) & (mock_uncont['Z'] >= z_min) 
    sel_in_mock_cont = DR9(region)[mock_cont_pix_number] & (mock_cont['Z'] <= z_max) & (mock_cont['Z'] >= z_min) 

    k, poles = compute_power(mock_uncont[sel_in_mock_uncont], randoms[sel_in_randoms], ells=(0), return_plot=True)
    k2, poles2 = compute_power(mock_cont[sel_in_mock_cont], randoms[sel_in_randoms], ells=(0), return_plot=True)
    k3, poles3 = compute_power(mock_cont[sel_in_mock_cont], randoms[sel_in_randoms], ells=(0), data_weights=wsys_new(mock_cont[sel_in_mock_cont]['RA'], mock_cont[sel_in_mock_cont]['DEC']), return_plot=True)

    plt.subplot(131+j)
    j += 1
    print(321+j)
    color = ['b', 'r', 'g']
    for i, ell in enumerate(poles.ells):
        plt.plot(k, poles(ell=ell, complex=False), marker='o', color=color[i], ls='-', label='uncont $\ell = {:d}$'.format(ell))
        plt.plot(k, poles2(ell=ell, complex=False), marker='.', color=color[i], ls=':', label='cont $\ell = {:d}$'.format(ell))
        plt.plot(k, poles3(ell=ell, complex=False), marker='x', color=color[i], ls='--', label='cont + correction $\ell = {:d}$'.format(ell))
    plt.legend(title=region, loc='upper right')
    plt.yscale('log')
    plt.xscale('log')
    plt.ylim(1e4, 1e5)
    plt.xlabel('$k$ [$h/\mathrm{Mpc}$]')
    plt.ylabel(r'$P(k)$ [$(\mathrm{Mpc}/h)^{3}$]')

plt.tight_layout()
plt.savefig('Mock_LRG_power_test.pdf')
plt.show()
# Out:
# [002934.48] 22-07-11 02:05  Notebook             INFO     Use default edges: np.linspace(0, 0.3, 81)
# [002935.37] 22-07-11 02:05  CatalogFFTPower      INFO     Painting catalog 1 to mesh CatalogMesh(nmesh=[512 512 512], boxsize=[10279.51640823 10279.51640823 10279.51640823], boxcenter=[-465.97287548  -12.14680165 1051.77512543], dtype=float64).
# [002935.89] 22-07-11 02:05  CatalogMesh          INFO     Slab 0 ~ 4194304 / 799625.
# [002936.42] 22-07-11 02:05  CatalogMesh          INFO     Painted 799625 out of 799625 objects to mesh.
# [002936.43] 22-07-11 02:05  CatalogMesh          INFO     Slab 0 ~ 4194304 / 794925.
# [002936.92] 22-07-11 02:05  CatalogMesh          INFO     Painted 794925 out of 794925 objects to mesh.
# [002936.92] 22-07-11 02:05  CatalogMesh          INFO     Running interlacing at order 2.
# [002940.68] 22-07-11 02:05  CatalogMesh          INFO     Slab 0 ~ 4194304 / 799625.
# [002941.15] 22-07-11 02:05  CatalogMesh          INFO     Painted 799625 out of 799625 objects to mesh.
# [002941.16] 22-07-11 02:05  CatalogMesh          INFO     Slab 0 ~ 4194304 / 794925.
# [002941.65] 22-07-11 02:05  CatalogMesh          INFO     Painted 794925 out of 794925 objects to mesh.
# [002951.30] 22-07-11 02:05  CatalogFFTPower      INFO     Done painting catalog 1 to mesh.
# [002951.30] 22-07-11 02:05  CatalogFFTPower      INFO     Using 80 k-bins between 0.000 and 0.300.
# [002951.81] 22-07-11 02:05  CatalogMesh          INFO     Slab 0 ~ 4194304 / 799625.
# [002952.26] 22-07-11 02:05  CatalogMesh          INFO     Painted 799625 out of 799625 objects to mesh.
# [002952.62] 22-07-11 02:05  CatalogMesh          INFO     Slab 0 ~ 4194304 / 794925.
# [002953.06] 22-07-11 02:05  CatalogMesh          INFO     Painted 794925 out of 794925 objects to mesh.
# [002953.45] 22-07-11 02:05  CatalogFFTPower      INFO     Meshes prepared in elapsed time 18.08 s.
# [002953.45] 22-07-11 02:05  CatalogFFTPower      INFO     Running mesh calculation.
# [002968.28] 22-07-11 02:05  CatalogFFTPower      INFO     ell = 0 done; 1 r2c completed
# [002968.32] 22-07-11 02:05  CatalogFFTPower      INFO     Mesh calculations performed in elapsed time 14.87 s.
# [002968.32] 22-07-11 02:05  CatalogFFTPower      INFO     Power spectrum computed in elapsed time 32.95 s.
# [002968.33] 22-07-11 02:05  wrapper              INFO     ----> Function "compute_power" took : 00:00:33.843 sec
# [002968.44] 22-07-11 02:05  Notebook             INFO     Use default edges: np.linspace(0, 0.3, 81)
# [002969.23] 22-07-11 02:05  CatalogFFTPower      INFO     Painting catalog 1 to mesh CatalogMesh(nmesh=[512 512 512], boxsize=[10279.51640823 10279.51640823 10279.51640823], boxcenter=[-465.97287548  -12.14680165 1051.77512543], dtype=float64).
# [002969.74] 22-07-11 02:05  CatalogMesh          INFO     Slab 0 ~ 4194304 / 607747.
# [002970.19] 22-07-11 02:05  CatalogMesh          INFO     Painted 607747 out of 607747 objects to mesh.
# [002970.21] 22-07-11 02:05  CatalogMesh          INFO     Slab 0 ~ 4194304 / 794925.
# [002970.70] 22-07-11 02:05  CatalogMesh          INFO     Painted 794925 out of 794925 objects to mesh.
# [002970.70] 22-07-11 02:05  CatalogMesh          INFO     Running interlacing at order 2.
# [002974.37] 22-07-11 02:05  CatalogMesh          INFO     Slab 0 ~ 4194304 / 607747.
# [002974.76] 22-07-11 02:05  CatalogMesh          INFO     Painted 607747 out of 607747 objects to mesh.
# [002974.78] 22-07-11 02:05  CatalogMesh          INFO     Slab 0 ~ 4194304 / 794925.
# [002975.27] 22-07-11 02:05  CatalogMesh          INFO     Painted 794925 out of 794925 objects to mesh.
# [002985.07] 22-07-11 02:06  CatalogFFTPower      INFO     Done painting catalog 1 to mesh.
# [002985.07] 22-07-11 02:06  CatalogFFTPower      INFO     Using 80 k-bins between 0.000 and 0.300.
# [002985.54] 22-07-11 02:06  CatalogMesh          INFO     Slab 0 ~ 4194304 / 607747.
# [002985.95] 22-07-11 02:06  CatalogMesh          INFO     Painted 607747 out of 607747 objects to mesh.
# [002986.28] 22-07-11 02:06  CatalogMesh          INFO     Slab 0 ~ 4194304 / 794925.
# [002986.72] 22-07-11 02:06  CatalogMesh          INFO     Painted 794925 out of 794925 objects to mesh.
# [002987.10] 22-07-11 02:06  CatalogFFTPower      INFO     Meshes prepared in elapsed time 17.87 s.
# [002987.10] 22-07-11 02:06  CatalogFFTPower      INFO     Running mesh calculation.
# [003002.15] 22-07-11 02:06  CatalogFFTPower      INFO     ell = 0 done; 1 r2c completed
# [003002.19] 22-07-11 02:06  CatalogFFTPower      INFO     Mesh calculations performed in elapsed time 15.09 s.
# [003002.19] 22-07-11 02:06  CatalogFFTPower      INFO     Power spectrum computed in elapsed time 32.96 s.
# [003002.20] 22-07-11 02:06  wrapper              INFO     ----> Function "compute_power" took : 00:00:33.758 sec
# [003002.40] 22-07-11 02:06  Notebook             INFO     Use default edges: np.linspace(0, 0.3, 81)
# [003003.18] 22-07-11 02:06  CatalogFFTPower      INFO     Painting catalog 1 to mesh CatalogMesh(nmesh=[512 512 512], boxsize=[10279.51640823 10279.51640823 10279.51640823], boxcenter=[-465.97287548  -12.14680165 1051.77512543], dtype=float64).
# [003003.71] 22-07-11 02:06  CatalogMesh          INFO     Slab 0 ~ 4194304 / 607747.
# [003004.16] 22-07-11 02:06  CatalogMesh          INFO     Painted 607747 out of 607747 objects to mesh.
# [003004.18] 22-07-11 02:06  CatalogMesh          INFO     Slab 0 ~ 4194304 / 794925.
# [003004.66] 22-07-11 02:06  CatalogMesh          INFO     Painted 794925 out of 794925 objects to mesh.
# [003004.66] 22-07-11 02:06  CatalogMesh          INFO     Running interlacing at order 2.
# [003008.69] 22-07-11 02:06  CatalogMesh          INFO     Slab 0 ~ 4194304 / 607747.
# [003009.08] 22-07-11 02:06  CatalogMesh          INFO     Painted 607747 out of 607747 objects to mesh.
# [003009.10] 22-07-11 02:06  CatalogMesh          INFO     Slab 0 ~ 4194304 / 794925.
# [003009.60] 22-07-11 02:06  CatalogMesh          INFO     Painted 794925 out of 794925 objects to mesh.
# [003019.61] 22-07-11 02:06  CatalogFFTPower      INFO     Done painting catalog 1 to mesh.
# [003019.61] 22-07-11 02:06  CatalogFFTPower      INFO     Using 80 k-bins between 0.000 and 0.300.
# [003020.09] 22-07-11 02:06  CatalogMesh          INFO     Slab 0 ~ 4194304 / 607747.
# [003020.47] 22-07-11 02:06  CatalogMesh          INFO     Painted 607747 out of 607747 objects to mesh.
# [003020.79] 22-07-11 02:06  CatalogMesh          INFO     Slab 0 ~ 4194304 / 794925.
# [003021.22] 22-07-11 02:06  CatalogMesh          INFO     Painted 794925 out of 794925 objects to mesh.
# [003021.59] 22-07-11 02:06  CatalogFFTPower      INFO     Meshes prepared in elapsed time 18.41 s.
# [003021.59] 22-07-11 02:06  CatalogFFTPower      INFO     Running mesh calculation.
# [003036.57] 22-07-11 02:06  CatalogFFTPower      INFO     ell = 0 done; 1 r2c completed
# [003036.61] 22-07-11 02:06  CatalogFFTPower      INFO     Mesh calculations performed in elapsed time 15.02 s.
# [003036.61] 22-07-11 02:06  CatalogFFTPower      INFO     Power spectrum computed in elapsed time 33.43 s.
# [003036.61] 22-07-11 02:06  wrapper              INFO     ----> Function "compute_power" took : 00:00:34.214 sec
# 322
# [003040.05] 22-07-11 02:06  Notebook             INFO     Use default edges: np.linspace(0, 0.3, 81)
# [003041.86] 22-07-11 02:07  CatalogFFTPower      INFO     Painting catalog 1 to mesh CatalogMesh(nmesh=[512 512 512], boxsize=[12271.33452906 12271.33452906 12271.33452906], boxcenter=[ -0.78028605  -9.42810737 213.09429547], dtype=float64).
# [003042.39] 22-07-11 02:07  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1480144.
# [003043.23] 22-07-11 02:07  CatalogMesh          INFO     Painted 1480144 out of 1480144 objects to mesh.
# [003043.25] 22-07-11 02:07  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1473145.
# [003044.08] 22-07-11 02:07  CatalogMesh          INFO     Painted 1473145 out of 1473145 objects to mesh.
# [003044.08] 22-07-11 02:07  CatalogMesh          INFO     Running interlacing at order 2.
# [003047.88] 22-07-11 02:07  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1480144.
# [003048.76] 22-07-11 02:07  CatalogMesh          INFO     Painted 1480144 out of 1480144 objects to mesh.
# [003048.78] 22-07-11 02:07  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1473145.
# [003049.67] 22-07-11 02:07  CatalogMesh          INFO     Painted 1473145 out of 1473145 objects to mesh.
# [003059.51] 22-07-11 02:07  CatalogFFTPower      INFO     Done painting catalog 1 to mesh.
# [003059.51] 22-07-11 02:07  CatalogFFTPower      INFO     Using 80 k-bins between 0.000 and 0.300.
# [003060.51] 22-07-11 02:07  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1480144.
# [003061.28] 22-07-11 02:07  CatalogMesh          INFO     Painted 1480144 out of 1480144 objects to mesh.
# [003061.91] 22-07-11 02:07  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1473145.
# [003062.65] 22-07-11 02:07  CatalogMesh          INFO     Painted 1473145 out of 1473145 objects to mesh.
# [003063.32] 22-07-11 02:07  CatalogFFTPower      INFO     Meshes prepared in elapsed time 21.46 s.
# [003063.32] 22-07-11 02:07  CatalogFFTPower      INFO     Running mesh calculation.
# [003078.36] 22-07-11 02:07  CatalogFFTPower      INFO     ell = 0 done; 1 r2c completed
# [003078.42] 22-07-11 02:07  CatalogFFTPower      INFO     Mesh calculations performed in elapsed time 15.10 s.
# [003078.42] 22-07-11 02:07  CatalogFFTPower      INFO     Power spectrum computed in elapsed time 36.56 s.
# [003078.43] 22-07-11 02:07  wrapper              INFO     ----> Function "compute_power" took : 00:00:38.373 sec
# [003078.65] 22-07-11 02:07  Notebook             INFO     Use default edges: np.linspace(0, 0.3, 81)
# [003080.20] 22-07-11 02:07  CatalogFFTPower      INFO     Painting catalog 1 to mesh CatalogMesh(nmesh=[512 512 512], boxsize=[12271.33452906 12271.33452906 12271.33452906], boxcenter=[ -0.78028605  -9.4955291  213.09429547], dtype=float64).
# [003080.72] 22-07-11 02:07  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1136408.
# [003081.37] 22-07-11 02:07  CatalogMesh          INFO     Painted 1136408 out of 1136408 objects to mesh.
# [003081.39] 22-07-11 02:07  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1473145.
# [003082.19] 22-07-11 02:07  CatalogMesh          INFO     Painted 1473145 out of 1473145 objects to mesh.
# [003082.19] 22-07-11 02:07  CatalogMesh          INFO     Running interlacing at order 2.
# [003085.98] 22-07-11 02:07  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1136408.
# [003086.61] 22-07-11 02:07  CatalogMesh          INFO     Painted 1136408 out of 1136408 objects to mesh.
# [003086.63] 22-07-11 02:07  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1473145.
# [003087.43] 22-07-11 02:07  CatalogMesh          INFO     Painted 1473145 out of 1473145 objects to mesh.
# [003097.41] 22-07-11 02:07  CatalogFFTPower      INFO     Done painting catalog 1 to mesh.
# [003097.41] 22-07-11 02:07  CatalogFFTPower      INFO     Using 80 k-bins between 0.000 and 0.300.
# [003098.27] 22-07-11 02:07  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1136408.
# [003098.85] 22-07-11 02:07  CatalogMesh          INFO     Painted 1136408 out of 1136408 objects to mesh.
# [003099.43] 22-07-11 02:07  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1473145.
# [003100.19] 22-07-11 02:07  CatalogMesh          INFO     Painted 1473145 out of 1473145 objects to mesh.
# [003100.85] 22-07-11 02:07  CatalogFFTPower      INFO     Meshes prepared in elapsed time 20.66 s.
# [003100.85] 22-07-11 02:07  CatalogFFTPower      INFO     Running mesh calculation.
# [003116.10] 22-07-11 02:08  CatalogFFTPower      INFO     ell = 0 done; 1 r2c completed
# [003116.15] 22-07-11 02:08  CatalogFFTPower      INFO     Mesh calculations performed in elapsed time 15.29 s.
# [003116.15] 22-07-11 02:08  CatalogFFTPower      INFO     Power spectrum computed in elapsed time 35.95 s.
# [003116.15] 22-07-11 02:08  wrapper              INFO     ----> Function "compute_power" took : 00:00:37.505 sec
# [003116.54] 22-07-11 02:08  Notebook             INFO     Use default edges: np.linspace(0, 0.3, 81)
# [003118.03] 22-07-11 02:08  CatalogFFTPower      INFO     Painting catalog 1 to mesh CatalogMesh(nmesh=[512 512 512], boxsize=[12271.33452906 12271.33452906 12271.33452906], boxcenter=[ -0.78028605  -9.4955291  213.09429547], dtype=float64).
# [003118.58] 22-07-11 02:08  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1136408.
# [003119.25] 22-07-11 02:08  CatalogMesh          INFO     Painted 1136408 out of 1136408 objects to mesh.
# [003119.27] 22-07-11 02:08  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1473145.
# [003120.12] 22-07-11 02:08  CatalogMesh          INFO     Painted 1473145 out of 1473145 objects to mesh.
# [003120.12] 22-07-11 02:08  CatalogMesh          INFO     Running interlacing at order 2.
# [003124.00] 22-07-11 02:08  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1136408.
# [003124.64] 22-07-11 02:08  CatalogMesh          INFO     Painted 1136408 out of 1136408 objects to mesh.
# [003124.66] 22-07-11 02:08  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1473145.
# [003125.50] 22-07-11 02:08  CatalogMesh          INFO     Painted 1473145 out of 1473145 objects to mesh.
# [003135.31] 22-07-11 02:08  CatalogFFTPower      INFO     Done painting catalog 1 to mesh.
# [003135.31] 22-07-11 02:08  CatalogFFTPower      INFO     Using 80 k-bins between 0.000 and 0.300.
# [003136.16] 22-07-11 02:08  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1136408.
# [003136.81] 22-07-11 02:08  CatalogMesh          INFO     Painted 1136408 out of 1136408 objects to mesh.
# [003137.39] 22-07-11 02:08  CatalogMesh          INFO     Slab 0 ~ 4194304 / 1473145.
# [003138.14] 22-07-11 02:08  CatalogMesh          INFO     Painted 1473145 out of 1473145 objects to mesh.
# [003138.81] 22-07-11 02:08  CatalogFFTPower      INFO     Meshes prepared in elapsed time 20.78 s.
# [003138.81] 22-07-11 02:08  CatalogFFTPower      INFO     Running mesh calculation.
# [003154.02] 22-07-11 02:08  CatalogFFTPower      INFO     ell = 0 done; 1 r2c completed
# [003154.06] 22-07-11 02:08  CatalogFFTPower      INFO     Mesh calculations performed in elapsed time 15.25 s.
# [003154.06] 22-07-11 02:08  CatalogFFTPower      INFO     Power spectrum computed in elapsed time 36.03 s.
# [003154.06] 22-07-11 02:08  wrapper              INFO     ----> Function "compute_power" took : 00:00:37.519 sec
# 323
# [003157.43] 22-07-11 02:08  Notebook             INFO     Use default edges: np.linspace(0, 0.3, 81)
# [003158.28] 22-07-11 02:08  CatalogFFTPower      INFO     Painting catalog 1 to mesh CatalogMesh(nmesh=[512 512 512], boxsize=[9950.77788531 9950.77788531 9950.77788531], boxcenter=[ 702.3360053   204.59487346 -646.29584657], dtype=float64).
# [003158.80] 22-07-11 02:08  CatalogMesh          INFO     Slab 0 ~ 4194304 / 760013.
# [003159.29] 22-07-11 02:08  CatalogMesh          INFO     Painted 760013 out of 760013 objects to mesh.
# [003159.31] 22-07-11 02:08  CatalogMesh          INFO     Slab 0 ~ 4194304 / 763444.
# [003159.81] 22-07-11 02:08  CatalogMesh          INFO     Painted 763444 out of 763444 objects to mesh.
# [003159.81] 22-07-11 02:08  CatalogMesh          INFO     Running interlacing at order 2.
# [003163.62] 22-07-11 02:09  CatalogMesh          INFO     Slab 0 ~ 4194304 / 760013.
# [003164.13] 22-07-11 02:09  CatalogMesh          INFO     Painted 760013 out of 760013 objects to mesh.
# [003164.14] 22-07-11 02:09  CatalogMesh          INFO     Slab 0 ~ 4194304 / 763444.
# [003164.64] 22-07-11 02:09  CatalogMesh          INFO     Painted 763444 out of 763444 objects to mesh.
# [003174.41] 22-07-11 02:09  CatalogFFTPower      INFO     Done painting catalog 1 to mesh.
# [003174.41] 22-07-11 02:09  CatalogFFTPower      INFO     Using 80 k-bins between 0.000 and 0.300.
# [003174.89] 22-07-11 02:09  CatalogMesh          INFO     Slab 0 ~ 4194304 / 760013.
# [003175.32] 22-07-11 02:09  CatalogMesh          INFO     Painted 760013 out of 760013 objects to mesh.
# [003175.65] 22-07-11 02:09  CatalogMesh          INFO     Slab 0 ~ 4194304 / 763444.
# [003176.09] 22-07-11 02:09  CatalogMesh          INFO     Painted 763444 out of 763444 objects to mesh.
# [003176.45] 22-07-11 02:09  CatalogFFTPower      INFO     Meshes prepared in elapsed time 18.17 s.
# [003176.45] 22-07-11 02:09  CatalogFFTPower      INFO     Running mesh calculation.
# [003191.51] 22-07-11 02:09  CatalogFFTPower      INFO     ell = 0 done; 1 r2c completed
# [003191.55] 22-07-11 02:09  CatalogFFTPower      INFO     Mesh calculations performed in elapsed time 15.10 s.
# [003191.55] 22-07-11 02:09  CatalogFFTPower      INFO     Power spectrum computed in elapsed time 33.27 s.
# [003191.56] 22-07-11 02:09  wrapper              INFO     ----> Function "compute_power" took : 00:00:34.122 sec
# [003191.67] 22-07-11 02:09  Notebook             INFO     Use default edges: np.linspace(0, 0.3, 81)
# [003192.40] 22-07-11 02:09  CatalogFFTPower      INFO     Painting catalog 1 to mesh CatalogMesh(nmesh=[512 512 512], boxsize=[9950.77788531 9950.77788531 9950.77788531], boxcenter=[ 702.3360053   204.59487346 -646.46672775], dtype=float64).
# [003192.92] 22-07-11 02:09  CatalogMesh          INFO     Slab 0 ~ 4194304 / 546658.
# [003193.30] 22-07-11 02:09  CatalogMesh          INFO     Painted 546658 out of 546658 objects to mesh.
# [003193.31] 22-07-11 02:09  CatalogMesh          INFO     Slab 0 ~ 4194304 / 763444.
# [003193.77] 22-07-11 02:09  CatalogMesh          INFO     Painted 763444 out of 763444 objects to mesh.
# [003193.77] 22-07-11 02:09  CatalogMesh          INFO     Running interlacing at order 2.
# [003197.48] 22-07-11 02:09  CatalogMesh          INFO     Slab 0 ~ 4194304 / 546658.
# [003197.83] 22-07-11 02:09  CatalogMesh          INFO     Painted 546658 out of 546658 objects to mesh.
# [003197.84] 22-07-11 02:09  CatalogMesh          INFO     Slab 0 ~ 4194304 / 763444.
# [003198.32] 22-07-11 02:09  CatalogMesh          INFO     Painted 763444 out of 763444 objects to mesh.
# [003208.14] 22-07-11 02:09  CatalogFFTPower      INFO     Done painting catalog 1 to mesh.
# [003208.14] 22-07-11 02:09  CatalogFFTPower      INFO     Using 80 k-bins between 0.000 and 0.300.
# [003208.58] 22-07-11 02:09  CatalogMesh          INFO     Slab 0 ~ 4194304 / 546658.
# [003208.92] 22-07-11 02:09  CatalogMesh          INFO     Painted 546658 out of 546658 objects to mesh.
# [003209.22] 22-07-11 02:09  CatalogMesh          INFO     Slab 0 ~ 4194304 / 763444.
# [003209.65] 22-07-11 02:09  CatalogMesh          INFO     Painted 763444 out of 763444 objects to mesh.
# [003210.01] 22-07-11 02:09  CatalogFFTPower      INFO     Meshes prepared in elapsed time 17.61 s.
# [003210.01] 22-07-11 02:09  CatalogFFTPower      INFO     Running mesh calculation.
# [003225.38] 22-07-11 02:10  CatalogFFTPower      INFO     ell = 0 done; 1 r2c completed
# [003225.42] 22-07-11 02:10  CatalogFFTPower      INFO     Mesh calculations performed in elapsed time 15.41 s.
# [003225.42] 22-07-11 02:10  CatalogFFTPower      INFO     Power spectrum computed in elapsed time 33.02 s.
# [003225.43] 22-07-11 02:10  wrapper              INFO     ----> Function "compute_power" took : 00:00:33.765 sec
# [003225.63] 22-07-11 02:10  Notebook             INFO     Use default edges: np.linspace(0, 0.3, 81)
# [003226.34] 22-07-11 02:10  CatalogFFTPower      INFO     Painting catalog 1 to mesh CatalogMesh(nmesh=[512 512 512], boxsize=[9950.77788531 9950.77788531 9950.77788531], boxcenter=[ 702.3360053   204.59487346 -646.46672775], dtype=float64).
# [003226.86] 22-07-11 02:10  CatalogMesh          INFO     Slab 0 ~ 4194304 / 546658.
# [003227.25] 22-07-11 02:10  CatalogMesh          INFO     Painted 546658 out of 546658 objects to mesh.
# [003227.26] 22-07-11 02:10  CatalogMesh          INFO     Slab 0 ~ 4194304 / 763444.
# [003227.73] 22-07-11 02:10  CatalogMesh          INFO     Painted 763444 out of 763444 objects to mesh.
# [003227.73] 22-07-11 02:10  CatalogMesh          INFO     Running interlacing at order 2.
# [003231.57] 22-07-11 02:10  CatalogMesh          INFO     Slab 0 ~ 4194304 / 546658.
# [003231.93] 22-07-11 02:10  CatalogMesh          INFO     Painted 546658 out of 546658 objects to mesh.
# [003231.95] 22-07-11 02:10  CatalogMesh          INFO     Slab 0 ~ 4194304 / 763444.
# [003232.41] 22-07-11 02:10  CatalogMesh          INFO     Painted 763444 out of 763444 objects to mesh.
# [003242.38] 22-07-11 02:10  CatalogFFTPower      INFO     Done painting catalog 1 to mesh.
# [003242.38] 22-07-11 02:10  CatalogFFTPower      INFO     Using 80 k-bins between 0.000 and 0.300.
# [003242.81] 22-07-11 02:10  CatalogMesh          INFO     Slab 0 ~ 4194304 / 546658.
# [003243.14] 22-07-11 02:10  CatalogMesh          INFO     Painted 546658 out of 546658 objects to mesh.
# [003243.43] 22-07-11 02:10  CatalogMesh          INFO     Slab 0 ~ 4194304 / 763444.
# [003243.84] 22-07-11 02:10  CatalogMesh          INFO     Painted 763444 out of 763444 objects to mesh.
# [003244.18] 22-07-11 02:10  CatalogFFTPower      INFO     Meshes prepared in elapsed time 17.84 s.
# [003244.18] 22-07-11 02:10  CatalogFFTPower      INFO     Running mesh calculation.
# [003259.17] 22-07-11 02:10  CatalogFFTPower      INFO     ell = 0 done; 1 r2c completed
# [003259.22] 22-07-11 02:10  CatalogFFTPower      INFO     Mesh calculations performed in elapsed time 15.03 s.
# [003259.22] 22-07-11 02:10  CatalogFFTPower      INFO     Power spectrum computed in elapsed time 32.88 s.
# [003259.22] 22-07-11 02:10  wrapper              INFO     ----> Function "compute_power" took : 00:00:33.597 sec
# 324
